# %% [markdown]
# ### I am going to check if (some of) the HD direction cells are actually moving direction cells

# %%
import os
import shutil
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve1d
from numpy import deg2rad
from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter1d
from scipy.interpolate import interp1d

# %%
def load_data(ratname, file_path):
    # Load the .mat file
    with h5py.File(file_path, 'r') as f:
        # List all keys
        keys = list(f.keys())
        #print(f"Keys: {keys}")

        # Access the sdata structure
        sdata = f['sdata']

        # Check if 'light1' exists in sdata
        if 'light1' not in sdata:
            print(f"'light1' not found in {file_path}")
            return None

        # Accessing the light1 group and its datasets
        light1 = sdata['light1']
        ppox = np.array(light1['pox'])
        ppoy = np.array(light1['poy'])
        pot = np.array(light1['pot'])
        poh = np.array(light1['poh'])
        pov = np.array(light1['pov'])
        f0 = np.array(light1['F0'])
        sintcptFreqy = np.array(light1['sintcptFreqy'])

        # Extract all cells containing the name 'R222'
        cell_names = [key for key in sdata.keys() if ratname in key]
        #print(f"Cell Names: {cell_names}")

        # Initialize dictionary to store data for all cells
        cells_data = {}

        # Iterate over each cell name and extract data
        for cell_name in cell_names:
            part_now = 'light1'  # Assuming 'light1' is the part_now equivalent

            pspx = np.array(sdata[cell_name][part_now]['spx'])
            pspy = np.array(sdata[cell_name][part_now]['spy'])
            pspt = np.array(sdata[cell_name][part_now]['spt'])
            pspv = np.array(sdata[cell_name][part_now]['spv'])
            psph = np.array(sdata[cell_name][part_now]['sph'])
            pspm = np.array(sdata[cell_name][part_now]['spm'])
            pval = np.array(sdata[cell_name][part_now]['pval'])
            spike_phase = np.array(sdata[cell_name][part_now]['spike_phase'])
            autocorrelogram = np.array(sdata[cell_name][part_now]['theta_train_long2'])
            hd_mean = np.array(sdata[cell_name][part_now]['hd_mean'])
            hd_std = np.array(sdata[cell_name][part_now]['hd_stdev'])
            tune_width = np.array(sdata[cell_name][part_now]['tuning_width'])
            intrinsic_freq = np.array(sdata[cell_name][part_now]['intrinsic_theta_frequency'])

            # Extract and decode cell_type
            cell_type_array = np.array(sdata[cell_name][part_now]['thetacell_type'])
            cell_type = ''.join([chr(ascii_val[0]) for ascii_val in cell_type_array])

            # Store the data for this cell
            cells_data[cell_name] = {
                'pspx': pspx,
                'pspy': pspy,
                'pspt': pspt,
                'pspv': pspv,
                'psph': psph,
                'pspm': pspm,
                'pval': pval,
                'spike_phase': spike_phase,
                'autocorrelogram': autocorrelogram,
                'hd_mean': hd_mean,
                'hd_std': hd_std,
                'tune_width': tune_width,
                'intrinsic_freq': intrinsic_freq,
                'cell_type': cell_type
            }

        # Create a dictionary to store all the data
        data_dict = {
            'ppox': ppox,
            'ppoy': ppoy,
            'pot': pot,
            'poh': poh,
            'pov': pov,
            'f0': f0,
            'sintcptFreqy': sintcptFreqy,
            'cell_names': cell_names,
            'cells_data': cells_data
        }

        return data_dict

# %%
def calculate_angular_speed(poh, pot, sigma=5):
    """
    Calculate the head rotation speed (angular speed) from head direction and time data.

    Parameters:
    poh : np.array
        Array of head direction angles in degrees.
    pot : np.array
        Array of time points corresponding to the head direction angles.
    sigma : float
        Standard deviation for Gaussian kernel used in smoothing.

    Returns:
    angular_speed : np.array
        Array of angular speed values.
    """

    # Ensure head direction angles are in radians
    poh_rad = np.deg2rad(poh)

    # Convert angles to complex exponential form
    poh_complex = np.exp(1j * poh_rad)

    # Apply Gaussian smoothing to real and imaginary parts separately
    poh_smooth_real = gaussian_filter1d(poh_complex.real, sigma=sigma)
    poh_smooth_imag = gaussian_filter1d(poh_complex.imag, sigma=sigma)

    # Convert back to angles
    poh_smooth = np.angle(poh_smooth_real + 1j * poh_smooth_imag)

    # Calculate the time differences
    dt = np.diff(pot)

    # Calculate the angle differences
    dtheta = np.diff(poh_smooth)
    
    #deal with the jump between 0 and 2pi
    dtheta[dtheta > np.pi] -= 2 * np.pi
    dtheta[dtheta < -np.pi] += 2 * np.pi
    
    # Calculate the angular speed
    angular_speed = dtheta / dt
    
    angular_speed = angular_speed.flatten()

    #add one element to the beginning of angular_speed to make it the same length as poh
    angular_speed = np.insert(angular_speed, 0, angular_speed[0])

    return angular_speed

def get_angular_speed_at_spikes(pspt, pot, angular_speed):

    angular_speed_spike = []
    for spike_time in pspt:
        # Find the index of the closest time in pot
        index = np.argmin(np.abs(pot - spike_time))
        angular_speed_spike.append(angular_speed[index])
    
    return np.array(angular_speed_spike)

def find_continuous_periods(angular_speed, pot, speed_threshold=0.5, duration_threshold=1.0):
    if speed_threshold > 0:
        # Identify where angular speed exceeds the threshold
        above_threshold = angular_speed > speed_threshold
    elif speed_threshold < 0:
        # Identify where angular speed is below the threshold
        above_threshold = angular_speed < speed_threshold
    else:
        raise ValueError("Speed threshold must be non-zero")

    # Find the indices where the state changes
    change_indices = np.diff(above_threshold.astype(int), prepend=0, append=0)

    # Identify the start and end indices of the segments
    start_indices = np.where(change_indices == 1)[0]
    end_indices = np.where(change_indices == -1)[0]

    # Ensure there is a matching number of start and end indices
    if len(start_indices) > len(end_indices):
        end_indices = np.append(end_indices, len(angular_speed) - 1)
    elif len(end_indices) > len(start_indices):
        start_indices = np.insert(start_indices, 0, 0)

    continuous_periods = []
    for start, end in zip(start_indices, end_indices):
        if end >= len(pot):
            end = len(pot) - 1
        duration = pot[end] - pot[start]
        if duration >= duration_threshold:
            continuous_periods.append((pot[start], pot[end]))

    return continuous_periods

def compute_spike_array(spike_times, timestamps):
    """
    Compute the spike array from spike times and timestamps.
    """
    
    # Assume t is sorted. If not, you must sort it first.
    indices = np.searchsorted(timestamps, spike_times, side='right')

    # Ensure no out-of-bounds indices
    indices = np.clip(indices, 0, len(timestamps) - 1)

    # Adjust indices to always refer to the nearest timestamp
    # If the index points to the start of the array, no need to adjust
    # If not, check if the previous index is closer
    prev_close = (indices > 0) & (np.abs(timestamps[indices - 1] - spike_times) < np.abs(timestamps[indices] - spike_times))
    indices[prev_close] -= 1

    spike_array = np.zeros_like(timestamps)
    np.add.at(spike_array, indices, 1) #very fast!
    
    return spike_array

def calculate_intrinsic_frequency(autocorrelogram):
    def model(t, a, b, c, omega, t1, t2):
        return (a * (np.sin(2*np.pi*omega * t) + 1) + b) * np.exp(-np.abs(t) / t1) + c * np.exp(-t**2 / t2**2)
    
    # Fit the model to the autocorrelogram data
    initial_guess = [1, 0.1, 0.1, 8, 0.01, 0.01]  # Initial guesses for a, b, c, omega, t1, t2
    bounds = ([0, 0, 0, 6, 0, 0], [np.inf, np.inf, 0.8, 12, 0.05, 0.05])  # Bounds for the parameters

    autocorr = autocorrelogram[0, :]
    lags = autocorrelogram[1, :] / 1000  # Convert lags to seconds

    params, covariance = curve_fit(model, lags, autocorr, p0=initial_guess, bounds=bounds)
    # Extract the intrinsic frequency (omega)
    intrinsic_frequency = params[3]
    print(f"Intrinsic Theta Frequency: {intrinsic_frequency:.2f} Hz")
    
    return intrinsic_frequency  

def compute_autocorrelation(spike_array, bin_size=0.02, max_lag=0.5):
    # Number of bins for the max_lag
    max_lag_bins = int(max_lag / bin_size)
    autocorr = np.correlate(spike_array, spike_array, mode='full')
    mid_point = len(autocorr) // 2
    autocorr = autocorr[mid_point - max_lag_bins: mid_point + max_lag_bins + 1]
    
    # Normalize the autocorrelation values
    lags = np.arange(-max_lag_bins, max_lag_bins + 1) * bin_size  # Lags in seconds
    
    idx_range = np.where((lags >= 0.05) & (lags <= 0.25))[0]
    max_value = np.max(autocorr[idx_range])
    autocorr = autocorr / max_value
    autocorr = np.clip(autocorr, a_min=None, a_max=1)  # Clip values above 1
    
    lags_ms = lags * 1000  # Convert to ms
    
    # Convert autocorr, lags into a 2*n array
    return np.array([autocorr, lags_ms])

def get_autocorrelogram_move_still(ppoh, pot, pspt, config):

    speed_threshold = config['speed_threshold']
    duration_threshold = config['duration_threshold']
    speed_smooth_sigma = config['speed_smooth_sigma']

    #calculate angular speed
    angular_speed = calculate_angular_speed(ppoh, pot, sigma=speed_smooth_sigma)

    continuous_periods_CCW = find_continuous_periods(angular_speed, pot, speed_threshold=-speed_threshold, duration_threshold=duration_threshold)
    continuous_periods_CW = find_continuous_periods(angular_speed, pot, speed_threshold=speed_threshold, duration_threshold=duration_threshold)

    pspt_move = []
    for i in range(len(continuous_periods_CCW)):
        #keet pspt if it is in the continuous period
        pspt_move.extend(pspt[(pspt >= continuous_periods_CCW[i][0]) & (pspt <= continuous_periods_CCW[i][1])])
    for i in range(len(continuous_periods_CW)):
        #keet pspt if it is in the continuous period
        pspt_move.extend(pspt[(pspt >= continuous_periods_CW[i][0]) & (pspt <= continuous_periods_CW[i][1])])    

    #sort
    pspt_move = np.sort(pspt_move)

    spike_array = compute_spike_array(pspt_move, pot)
    autocorrelogram_move = compute_autocorrelation(spike_array, bin_size=0.02, max_lag=0.5) 

    #get remaining spike time
    pspt_rest = np.setdiff1d(pspt, pspt_move)
    spike_array = compute_spike_array(pspt_rest, pot)
    autocorrelogram_still = compute_autocorrelation(spike_array, bin_size=0.02, max_lag=0.5)

    return autocorrelogram_move, autocorrelogram_still


def compute_moving_direction(ppox, ppoy, pot, ppoh, temporal_smooth_sigma=5):
    """
    Calculate the moving direction based on position data and temporal smoothing.
    
    Parameters:
    ppox : np.array
        Array of x positions.
    ppoy : np.array
        Array of y positions.
    pot : np.array
        Array of time points.
    temporal_smooth_sigma : float
        Standard deviation for Gaussian kernel used in smoothing.
        
    Returns:
    moving_direction : np.array
        Array of moving direction angles in degrees.
    """
    
    # Convert int16 to float
    ppox = ppox.astype(float)
    ppoy = ppoy.astype(float)
    
    # Apply Gaussian smoothing to position data
    ppox_smooth = gaussian_filter1d(ppox, sigma=temporal_smooth_sigma)
    ppoy_smooth = gaussian_filter1d(ppoy, sigma=temporal_smooth_sigma)
    
    # Calculate the differences
    dx = np.diff(ppox_smooth)
    dy = np.diff(ppoy_smooth)
    
    # Identify non-movement periods (where both dx and dy are zero)
    moving_mask = (dx != 0) | (dy != 0)
    
    # print(moving_mask.shape[0], sum(moving_mask))
    
    # Calculate the moving direction in radians for moving periods
    moving_direction_rad = np.arctan2(dy[moving_mask], dx[moving_mask])
    
    # Convert to degrees
    moving_direction_deg = np.rad2deg(moving_direction_rad)
    
    # Adjust to range 0-360 degrees
    moving_direction_deg = np.mod(moving_direction_deg, 360)
    
    # Interpolate to fill in non-movement periods
    full_pot = pot[:-1]  # Exclude the last point to match the length of dx, dy
    interpolator = interp1d(full_pot[moving_mask], moving_direction_deg, kind='linear', bounds_error=False, fill_value='extrapolate')
    moving_direction_full = interpolator(full_pot)
    
    # Ensure moving_direction_full has the same length as pot by padding the end
    moving_direction_full = np.append(moving_direction_full, moving_direction_full[-1])
    
    # #now work out the constant offset between the moving direction and the head direction 
    # #and align moving_direction_full to head direction
    # all_offset = ppoh - moving_direction_full
    # #deal with the jump between 0 and 2pi
    # all_offset[all_offset > 180] -= 360
    # all_offset[all_offset < -180] += 360
    # offset = np.mean(all_offset)
    # print(f"Offset between moving direction and head direction: {offset:.2f} degrees")
    # moving_direction_full += offset
    
    # Ensure moving_direction_full is in the range 0-360 degrees
    moving_direction_full = np.mod(moving_direction_full, 360)
    
    # #check the offset again
    # all_offset = ppoh - moving_direction_full
    # #deal with the jump between 0 and 2pi
    # all_offset[all_offset > 180] -= 360
    # all_offset[all_offset < -180] += 360
    # offset = np.mean(all_offset)
    # print(f"Offset between moving direction and head direction after alignment: {offset:.2f} degrees")
    return moving_direction_full

def get_spike_direction(ppom, pot, pspt):
    """
    Get the moving direction for each spike event based on the closest time in pot.
    
    Parameters:
    ppom : np.array
        Array of moving direction angles in degrees.
    pot : np.array
        Array of time points corresponding to the moving direction.
    pspt : np.array
        Array of spike event times.
        
    Returns:
    spike_directions : np.array
        Array of moving direction angles at the spike event times.
    """
    spike_directions = []
    for spike_time in pspt:
        closest_time_idx = np.argmin(np.abs(pot - spike_time))
        spike_directions.append(ppom[closest_time_idx])
    
    return np.array(spike_directions)

def get_spike_times_large_diff(ppom, ppoh, pot, pspt, threshold=30):
    """
    Get spike times when the difference between moving direction and head direction is more than a threshold.

    Parameters:
    ppom : np.array
        Array of moving direction angles in degrees.
    ppoh : np.array
        Array of head direction angles in degrees.
    pot : np.array
        Array of time points corresponding to the moving direction and head direction.
    pspt : np.array
        Array of spike event times.
    threshold : float
        Threshold for the difference in degrees.

    Returns:
    spike_times_large_diff : np.array
        Array of spike times where the difference is more than the threshold.
    """
    ppoh = ppoh.flatten()
    
    # Compute the difference between ppom and ppoh, considering the circular nature of angles
    diff = np.abs(np.mod(ppom - ppoh + 180, 360) - 180)
    
    # Get the time points where the difference is more than the threshold
    large_diff_times = pot[diff > threshold]
    
    # Find the spike times that are close to these time points
    spike_times_large_diff = []
    for spike_time in pspt:
        closest_time_idx = np.argmin(np.abs(large_diff_times - spike_time))
        if np.abs(large_diff_times[closest_time_idx] - spike_time) < np.diff(pot).mean():  # Ensure the time difference is within the sampling interval
            spike_times_large_diff.append(spike_time)
    
    return np.array(spike_times_large_diff)

# %%
def plot_head_direction_tuning(ax, ppoh, psph, config, pos_tb=0.02):
    """
    Plot the head direction tuning map in a polar plot.

    Parameters:
    ax : matplotlib.axes._subplots.PolarAxesSubplot
        The polar axes to plot on.
    ppoh : np.array
        Array of session head direction angles in degrees.
    psph : np.array
        Array of cell head direction angles in degrees.
    pos_tb : float
        Time base for converting session HD to time.
    cell_name : str
        Name of the cell for which the tuning map is plotted.
    config : dict
        Configuration dictionary containing 'hd_bins' and 'hd_boxcar' parameters.
    """

    # Convert angles to radians
    ppoh_rad = deg2rad(ppoh)
    psph_rad = deg2rad(psph)

    # Calculate histograms for session and cell head directions
    hd1, _ = np.histogram(ppoh_rad, bins=config['hd_bins'], range=(0, 2 * np.pi))
    hd2, _ = np.histogram(psph_rad, bins=config['hd_bins'], range=(0, 2 * np.pi))

    # Boxcar filter
    boxcar_size = config['hd_boxcar']
    boxcar_filter = np.ones(boxcar_size) / boxcar_size

    # Apply boxcar filter
    hd1_filtered = convolve1d(hd1, boxcar_filter, mode='wrap')
    hd2_filtered = convolve1d(hd2, boxcar_filter, mode='wrap')

    # Convert session HD to time (i.e., dwelling time in each HD bin)
    hd1_time = hd1_filtered * pos_tb

    # Calculate HD firing rate
    hd3 = hd2_filtered / hd1_time

    # Normalize session HD
    hd1_normalized = hd1_time / np.max(hd1_time)

    # Normalize cell HD firing rate
    hd3_normalized = hd3 / np.max(hd3)
    hd3_normalized = hd3_normalized.flatten()

    # Close the loop by appending the first element to the end
    theta = np.linspace(0, 2 * np.pi, config['hd_bins'], endpoint=False)
    theta = np.append(theta, theta[0])
    hd1_normalized = np.append(hd1_normalized, hd1_normalized[0])
    hd3_normalized = np.append(hd3_normalized, hd3_normalized[0])

    # Plot the session head direction with shading
    ax.plot(theta, hd1_normalized, label='Session Head Direction', color='gray')
    ax.fill_between(theta, 0, hd1_normalized, facecolor='gray', alpha=0.2)

    # Plot the cell head direction firing rate
    ax.plot(theta, hd3_normalized, label='Cell Head Direction Firing Rate', color='#38c7ff')
    ax.fill_between(theta, 0, hd3_normalized, facecolor='#38c7ff', alpha=0.5)

    #keep 0 90 180 270 as the xticks
    ax.set_xticks([0, np.pi / 2, np.pi, 3 * np.pi / 2])
    ax.set_xticklabels(['0', '90', '180', '270'])
    
    #remove yticks
    ax.set_yticks([])
    
    #ax.set_title(cell_name + '\n'+str(np.round(hd_mean,1))+'('+str(np.round(hd_std,1))+')' +'\nRayleigh_p=' + str(np.round(pval, 4)), fontsize=10)
    
    # ax.set_title(f"{cell_name}\nAngle:{hd_mean:.0f} ({hd_std:.0f})\nTuning width:{tune_width:.0f}\nRayleigh_p={pval:.4f}", fontsize=10)
    # ax.legend()

    return ax

def plot_autocorrelogram(ax, autocorrelogram, cell_type):
    
    ax.plot(autocorrelogram[1,:], autocorrelogram[0,:], 'k')
    #fillin between y=0 and autocorrelogram
    ax.fill_between(autocorrelogram[1,:], 0, autocorrelogram[0,:], facecolor='black')
    # ax.set_xticks([-500, 0, 500])
    ax.set_yticks([])
    # ax.set_xlabel('Lag (ms)')
    ax.set_xticks([])
    ax.set_xlabel('')
    ax.set_title(cell_type)
    ax.axis('off')
    
    #set ylim as np.min(autocorrelogram[0,:]) and np.max(autocorrelogram[0,:])
    # ax.set_ylim(np.min(autocorrelogram[0,:]), np.max(autocorrelogram[0,:]))

    return ax

# %%
base_dir = '/home/zilong/Desktop/GridCellThetaSweeps/LomiData/'
output_dir = '/home/zilong/Desktop/GridCellThetaSweeps/figures/movingdirection/all/'
output_skip_dir = '/home/zilong/Desktop/GridCellThetaSweeps/figures/movingdirection/skip/'
output_nonskip_dir = '/home/zilong/Desktop/GridCellThetaSweeps/figures/movingdirection/nonskip/'
output_nontheta_dir = '/home/zilong/Desktop/GridCellThetaSweeps/figures/movingdirection/nontheta/'

# Configuration
config = {
    'hd_bins': 60,
    'hd_boxcar': 3,
    'speed_threshold': 0.5,
    'duration_threshold': 0.5,
    'speed_smooth_sigma': 2, 
    'movingdirection_sigma': 25, #time bin size 20 ms, so 5 is 100 ms
    'interpolation_factor': 2 #1 is 0.02s, and 2 is 0.01s
}

# Create output directories if they don't exist
for dir_path in [output_dir, output_skip_dir, output_nonskip_dir, output_nontheta_dir]:
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)    
    os.makedirs(dir_path)

total_hd_cells = 0

all_tw = []
nontheta_tw = []
theta_tw = []
theta_nonskip_tw = []
theta_skip_tw = []

matnames = {}

# Iterate through each subfolder in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    if os.path.isdir(subdir_path):
        # Iterate through each .mat file in the subfolder
        for file in os.listdir(subdir_path):
            if file.endswith('_sdata.mat'):
                file_path = os.path.join(subdir_path, file)
                print(f"Processing {file_path}")
                ratname = file.split('_')[0]
                data_dict = load_data(ratname, file_path)
                
                if data_dict is not None:
                    ppoh = data_dict['poh']
                    pot = data_dict['pot'].flatten()
                    ppox = data_dict['ppox'].flatten()
                    ppoy = data_dict['ppoy'].flatten()
                    
                    ppom = compute_moving_direction(ppox, ppoy, pot, ppoh, config['movingdirection_sigma'])
                    #print(np.min(ppom), np.max(ppom))
                    #interpolte pot 
                    sampling_interval = np.diff(pot).mean()
                    new_interval = sampling_interval / config['interpolation_factor']
                    pot_interp = np.arange(0, pot[-1], new_interval)
                    
                    for cell_name, cell_data in data_dict['cells_data'].items():
                        psph = cell_data['psph'].flatten()
                        pspt = cell_data['pspt'].flatten()
                        spike_phase = cell_data['spike_phase'].flatten()
                        pval = cell_data['pval'][0][0]
                        hd_mean = cell_data['hd_mean'][0][0]
                        hd_std = cell_data['hd_std'][0][0]
                        tune_width = cell_data['tune_width'][0][0]
                        autocorrelogram = cell_data['autocorrelogram']
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        cell_type = cell_data['cell_type']
                        
                        #get the spike moving direction called pspm, using the pspt and the calculated ppom
                        pspm = get_spike_direction(ppom, pot, pspt)
                        
                        #get the spike time when the difference between ppom and ppoh is more than 30 degree
                        pspt_diff = get_spike_times_large_diff(ppom, ppoh, pot, pspt, threshold=60)
                        psph_diff = get_spike_direction(ppoh.flatten(), pot, pspt_diff)
                        pspm_diff = get_spike_direction(ppom, pot, pspt_diff)
                        
                        #store matname for each cell
                        matnames[cell_name] = [ratname, file_path]
                        
                        if pval < 0.05: #select only head direction tuned cells
                            
                            try:
                                #plot
                                fig = plt.figure(figsize=(4,3))
                                gs=fig.add_gridspec(2, 3, width_ratios=[1, 2, 1])
                                
                                #plot head direction tuning map
                                ax0 = fig.add_subplot(gs[0, 0], projection='polar')
                                ax0 = plot_head_direction_tuning(ax0, ppoh, psph, config)
                                
                                #plot spike phase versus head direction, i.e., check phase precession
                                ax2 = fig.add_subplot(gs[0, 1])
                                spike_array = compute_spike_array(pspt, pot_interp)
                                autocorrelogram2 = compute_autocorrelation(spike_array, bin_size=new_interval, max_lag=0.5)                   
                                ax2 = plot_autocorrelogram(ax2, autocorrelogram2, cell_type)
                                
                                #plot phase precession
                                ax3 =  fig.add_subplot(gs[0, 2], projection='polar')
                                #plot moving direction tuning map
                                ax3 = plot_head_direction_tuning(ax3, ppom, pspm, config)
                                
                                ax4 = fig.add_subplot(gs[1, 0], projection='polar')
                                #plot head direction tuning map with difference spike time
                                ax4 = plot_head_direction_tuning(ax4, ppoh, psph_diff, config)

                                ax5  = fig.add_subplot(gs[1, 2], projection='polar')
                                #plot moving direction tuning map with difference spike time
                                ax5 = plot_head_direction_tuning(ax5, ppom, pspm_diff, config)
                                
                                output_path = os.path.join(output_dir, f"{cell_name}.png")
                                plt.tight_layout()
                                plt.savefig(output_path)
                                
                                #save tuning width
                                all_tw.append(tune_width)
                            
                                #save fig according to cell type in different folders
                                if 'ThetaxHD' in cell_type:
                                    
                                    #save tuning width
                                    theta_tw.append(tune_width)
                                                                        
                                    if 'skip'in cell_type:
                                        #save tuning width
                                        theta_skip_tw.append(tune_width)
                                        output_skip_path = os.path.join(output_skip_dir, f"{cell_name}.png")
                                        plt.savefig(output_skip_path)
                                    elif 'ThetaxHD' in cell_type:
                                        #save tuning width
                                        theta_nonskip_tw.append(tune_width)
                                        output_nonskip_path = os.path.join(output_nonskip_dir, f"{cell_name}.png")
                                        plt.savefig(output_nonskip_path)
                                elif 'HDC' in cell_type:
                                    nontheta_tw.append(tune_width)
                                    output_nontheta_path = os.path.join(output_nontheta_dir, f"{cell_name}.png")
                                    plt.savefig(output_nontheta_path)
                                    
                                plt.close(fig)
                                
                                total_hd_cells += 1
                            except Exception as e:
                                print(f"Error processing {cell_name}: {e}")
                        
print(f"Total number of HD cells processed: {total_hd_cells}")
# Out:
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_170719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_100919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_040919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_040919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_250719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_030919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_200819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_180719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_020819_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_120819_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_240719_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_260719_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_260719_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_310719_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_280819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_170919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_210819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_160819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_140819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_270819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_270819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_190719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_190719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_220819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_180819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_160919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r652/R652_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_31032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_09032020_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_11032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_20032020_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_14042020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_16032020_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_03042020_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_25032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_01042020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_16042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_10032020_T5_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_12032020_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_13032020_T8_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_19032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_18032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_30032020_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_22032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r448/R448_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_200919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_081019_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_310719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_040719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_150819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_031019_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_280619_T1b_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_230619_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_180819_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_180819_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_080719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_300619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_300619_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_220619_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_220619_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_060719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_130819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_071019_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_110919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_300919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_300919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_130919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_091019_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_260719_T6_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_210619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_210619_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_050719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_050719_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_101019_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_010719_T7_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_050819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_260619_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_290719_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_041019_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r651/R651_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_110119_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_030119_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_050119_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_030219_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_280219_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_160119_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_130119_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_190219_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_120119_T6_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_040119_T5_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_040119_T5_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_220219_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_310119_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_010219_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_070119_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_190119_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_200119_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_090219_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_060219_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_060219_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_290119_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_170119_T8_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_150219_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_140219_T4_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_270119_T7_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_220119_T8_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_120219_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_200119_T5_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_070219_T5_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_160219_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r762/R762_080119_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_30032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_17032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_16032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_31032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_11032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_20032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_10032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_18032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_01042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_25032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_19032020_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_22032020_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_14042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_03042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_13032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r449/R449_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_120319_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_060319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_280319_T5_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_130319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_220319_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_150319_T2_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_180319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_050319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_170319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_110319_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_110319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_140319_T1_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_260319_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_070319_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_070319_T3_sdata.mat
# Processing /home/zilong/Desktop/GridCellThetaSweeps/LomiData/DATA r222/R222_080319_T2_sdata.mat
# Total number of HD cells processed: 208
