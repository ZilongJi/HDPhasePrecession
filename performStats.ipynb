# %% [markdown]
# # This code is to summarize the statistical results related to phase precession of turning angle. Experimental data is based on Lomi et al, 2023. This code is written by Zilong Ji, 2024.

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from numpy import deg2rad
from scipy.optimize import curve_fit
from scipy.stats import mannwhitneyu, wilcoxon
import sys
sys.path.append('/home/zilong/Desktop/HDPhasePrecession/CircularLinearReg')
from core import cl_corr
import HD_utils

# %load_ext autoreload
# %autoreload 2

# %%
def sinmodel(t, a, b, c, omega, t1, t2):
    return (a * (np.sin(2*np.pi*omega * t + np.pi/2) + 1) + b) * np.exp(-np.abs(t) / t1) + c * np.exp(-t**2 / t2**2) 

def calculate_intrinsic_frequency(autocorrelogram):

    # Fit the model to the autocorrelogram data
    initial_guess = [1, 1, 0.1, 9, 1.0, 0.01]  # Initial guesses for a, b, c, omega, t1, t2
    bounds = ([0, 0, 0, 6, 0, 0], [100, 100, 0.8, 12, 8, 0.05])  # Bounds for the parameters

    autocorr = autocorrelogram[0, :]
    #normalze autocorr to 0-1
    lags = autocorrelogram[1, :] / 1000.  # Convert lags to seconds

    params, _ = curve_fit(sinmodel, lags, autocorr, p0=initial_guess, bounds=bounds)
    # Extract the intrinsic frequency (omega)
    intrinsic_frequency = params[3]
    print(f"Intrinsic Theta Frequency: {intrinsic_frequency:.2f} Hz")
    
    return intrinsic_frequency, params

def skipmodel(t, a1, a2, b, c, omega, t1, t2):
    return (a1 * (np.cos(2*np.pi*omega * t) + 1) + a2 * (np.cos(np.pi*omega * t) + 1) + b) * np.exp(-np.abs(t) / t1) + c * np.exp(-t**2 / t2**2)

def calculate_skipping_index(autocorrelogram):
    # Fit the model to the autocorrelogram data
    initial_guess = [0.5, 0.5, 0.1, 0.1, 2 * 8, 0.01, 0.01]  # Initial guesses for a1, a2, b, c, omega, t1, t2
    bounds = ([0, 0, 0, -1, 10, 0, 0], [10, 10, 1, 1, 18, 5., 0.05])  # Bounds for the parameters

    autocorr = autocorrelogram[0, :]
    lags = autocorrelogram[1, :] / 1000  # Convert lags to seconds

    params, covariance = curve_fit(skipmodel, lags, autocorr, p0=initial_guess, bounds=bounds)
    omega = params[4] #freq

    # Calculate p1 and p2
    p1 = skipmodel(2 * np.pi / omega, *params)
    p2 = skipmodel(4 * np.pi / omega, *params)

    # Calculate the theta cycle skipping index
    TS = (p2 - p1) / max(p1, p2)
    
    print(f"Omega: {omega:.2f} Hz")
    print(f"Theta Cycle Skipping Index: {TS:.2f}")
    
    return omega, TS, params  # Return frequency in Hz and the TS index

def get_phaseprecession(ppoh, pot, pspt, psph, hd_mean, spike_phase, config):
    
    spike_phase = spike_phase + np.pi #[-pi, pi] -> [0, 2pi]
    
    speed_threshold = config['speed_threshold']
    duration_threshold = config['duration_threshold']
    speed_smooth_sigma = config['speed_smooth_sigma']
    
    #calculate angular speed
    angular_speed = HD_utils.calculate_angular_speed(ppoh, pot, sigma=speed_smooth_sigma)
    
    #convert psph to radian
    psph = deg2rad(psph)
    hd_mean = deg2rad(hd_mean)
    
    psph_centered = np.mod(psph - hd_mean + np.pi, 2 * np.pi)
    
    #CCW plot in ax1
    continuous_periods_CCW = HD_utils.find_continuous_periods(angular_speed, pot, speed_threshold=-speed_threshold, duration_threshold=duration_threshold)
    indx = []
    for i in range(len(continuous_periods_CCW)):
        indx.extend(np.where((pspt > continuous_periods_CCW[i][0]) & (pspt < continuous_periods_CCW[i][1]))[0])
        
    psph_CCW = psph_centered[indx]
    spike_phase_CCW = spike_phase[indx]
    
    
    #CW plot in ax2
    continuous_periods_CW = HD_utils.find_continuous_periods(angular_speed, pot, speed_threshold=speed_threshold, duration_threshold=duration_threshold)
    #keep the index when pspt is within continuous_periods
    indx = [] 
    for i in range(len(continuous_periods_CW)):
        indx.extend(np.where((pspt > continuous_periods_CW[i][0]) & (pspt < continuous_periods_CW[i][1]))[0])
    
    psph_CW = psph_centered[indx]
    spike_phase_CW = spike_phase[indx]
    
    
    #ax3 plot
    #flip   psph_CCW by 2pi - psph_CCW
    psph_CCW = 2 * np.pi - psph_CCW
    #combine CCW and CW togther and plot
    psph_combined = np.concatenate((psph_CCW, psph_CW))
    spike_phase_combined = np.concatenate((spike_phase_CCW, spike_phase_CW))
    
    circ_lin_corr, pval, slope, phi0, RR = cl_corr(psph_combined, spike_phase_combined, min_slope=-1/2/np.pi, max_slope=1/2/np.pi, bootstrap_iter=1000, return_pval=True)
    

    return pval, circ_lin_corr

def plot_autocorrelogram(ax, autocorrelogram):

    labelsize = 10
    ticksize = 8
    
    autocorr = autocorrelogram[0, :]

    ax.plot(autocorrelogram[1,:], autocorr, color='k', label='Autocorrelogram')

    intrinsic_frequency, params = calculate_intrinsic_frequency(autocorrelogram)

    #plot the fitted curve
    t = autocorrelogram[1,:]/1000
    #get the predicted y one by one
    y = []
    for i in range(len(t)):
        y.append(sinmodel(t[i], *params))
        
    ax.plot(t*1000, sinmodel(t, *params), color='red', label='Fitted curve', linewidth=1)
    
    ax.legend(frameon=False, loc='upper center', fontsize=8, ncol=1, bbox_to_anchor=(0.5, 1.3))
    
    ax.set_xticks([-500, 0, 500])   
    
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False) 
    
    ax.set_xlabel('Lag (ms)', fontsize=labelsize)
    ax.set_ylabel('Autocorrelation', fontsize=labelsize)
    
    #set x and y tick fontsize to 8
    ax.tick_params(axis='x', which='major', labelsize=ticksize)
    ax.tick_params(axis='y', which='major', labelsize=ticksize)
    
    
    return ax, intrinsic_frequency

def plot_thetaskipping(ax, autocorrelogram):
    
    labelsize = 10
    ticksize = 8
    
    autocorr = autocorrelogram[0, :]

    ax.plot(autocorrelogram[1,:], autocorr, color='k', label='Autocorrelogram')

    omega, TS, params = calculate_skipping_index(autocorrelogram)

    #plot the fitted curve
    t = autocorrelogram[1,:]/1000
        
    ax.plot(t*1000, skipmodel(t, *params), color='red', label='Fitted curve', linewidth=1)
    
    ax.legend(frameon=False, loc='upper center', fontsize=8, ncol=1, bbox_to_anchor=(0.5, 1.3))
    
    ax.set_xticks([-500, 0, 500])   
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False) 
    
    ax.set_xlabel('Lag (ms)', fontsize=labelsize)
    ax.set_ylabel('Autocorrelation', fontsize=labelsize)
    
    #set x and y tick fontsize to 8
    ax.tick_params(axis='x', which='major', labelsize=ticksize)
    ax.tick_params(axis='y', which='major', labelsize=ticksize)
    
    
    return ax, TS

# %% [markdown]
# ## Section 1: extract information and perform circular-linear correlation analysis

# %%
base_dir = '/home/zilong/Desktop/HDPhasePrecession/LomiData'


# Configuration
config = {
    'hd_bins': 60,
    'hd_boxcar': 3,
    'speed_threshold': 0.5,
    'duration_threshold': 0.5,
    'speed_smooth_sigma': 40,  #0.8,0.8,40 gives 43% pp cells
    'movingdirection_sigma': 5, #time bin size 20 ms, so 5 is 100 ms
    'interpolation_factor': 1, #1 is 0.02s, and 2 is 0.01s
    'IFR_window':0.2
}

total_hd_cells = 0

all_tw = []
nontheta_tw = []
theta_tw = []
theta_nonskip_tw = []
theta_skip_tw = []

all_intrinsic_freq = []
nontheta_intrinsic_freq = []
theta_intrinsic_freq = []
theta_nonskip_intrinsic_freq = []
theta_skip_intrinsic_freq = []

all_global_freq = []
nontheta_global_freq = []
theta_global_freq = []
theta_nonskip_global_freq = []
theta_skip_global_freq = []

all_ppp = []
nontheta_ppp = []
theta_ppp = []
theta_nonskip_ppp = []
theta_skip_ppp = []

all_clr = []
nontheta_clr = []
theta_clr = []
theta_nonskip_clr = []
theta_skip_clr = []

matnames = {}

# Iterate through each subfolder in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    if os.path.isdir(subdir_path):
        # Iterate through each .mat file in the subfolder
        for file in os.listdir(subdir_path):
            if file.endswith('_sdata.mat'):
                file_path = os.path.join(subdir_path, file)
                print(f"Processing {file_path}")
                ratname = file.split('_')[0]
                data_dict = HD_utils.load_data(ratname, file_path)
                
                if data_dict is not None:
                    ppoh = data_dict['poh']
                    pot = data_dict['pot'].flatten()
                    
                    ppox = data_dict['ppox'].flatten()
                    ppoy = data_dict['ppoy'].flatten()
                    global_freq = data_dict['global_freq'][0][0]
                    
                    #interpolte pot 
                    sampling_interval = np.diff(pot).mean()
                    new_interval = sampling_interval / config['interpolation_factor']
                    pot_interp = np.arange(0, pot[-1], new_interval)
                    
                    for cell_name, cell_data in data_dict['cells_data'].items():
                        psph = cell_data['psph'].flatten()
                        pspt = cell_data['pspt'].flatten()
                        spike_phase = cell_data['spike_phase'].flatten()
                        hd_pval = cell_data['pval'][0][0]
                        hd_mean = cell_data['hd_mean'][0][0]
                        hd_std = cell_data['hd_std'][0][0]
                        tune_width = cell_data['tune_width'][0][0]
                        autocorrelogram = cell_data['autocorrelogram']
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        hd_rayleigh = cell_data['hd_rayleigh'][0][0]
                        hd_rayleigh_shuffle_99 = cell_data['hd_rayleigh_shuffle_99'][0][0]
                        peak_fr = cell_data['peak_fr'][0][0]
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        cell_type = cell_data['cell_type']
                        
                        #store matname for each cell
                        matnames[cell_name] = [ratname, file_path]
                        
                        #if hd_pval < 0.05: #select only head direction tuned cells
                        if hd_rayleigh > hd_rayleigh_shuffle_99 and peak_fr > 1: #select only head direction tuned cells with rayleigh vector > 99% shuffle and the peak firing rate in the directional field is greater than 1 Hz
                            try:
                                #get results for phase precession against tuning angle
                                pval, clr = get_phaseprecession(ppoh, pot, pspt, psph, hd_mean, spike_phase, config)
                                
                                #save tuning width
                                all_tw.append(tune_width)
                                all_intrinsic_freq.append(intrinsic_freq)
                                all_global_freq.append(global_freq)
                                #save ppp 
                                all_ppp.append(pval)
                                #save circ-linear correlation
                                all_clr.append(clr)
                            
                                #save fig according to cell type in different folders
                                if 'Strong ThetaxHD' in cell_type: #This is a theta modulated HD cell
                                    
                                    #save tuning width
                                    theta_tw.append(tune_width)
                                    theta_intrinsic_freq.append(intrinsic_freq)
                                    theta_global_freq.append(global_freq)
                                    #save ppp
                                    theta_ppp.append(pval)
                                    #save circ-linear correlation
                                    theta_clr.append(clr)
 
                                    if 'skip'in cell_type: #this is a theta skipping cell
                                        #save tuning width
                                        theta_skip_tw.append(tune_width)
                                        theta_skip_intrinsic_freq.append(intrinsic_freq)
                                        theta_skip_global_freq.append(global_freq)
                                        #save ppp
                                        theta_skip_ppp.append(pval)
                                        #save circ-linear correlation
                                        theta_skip_clr.append(clr)
                                    elif 'Strong ThetaxHD' in cell_type: #this is a theta modulated non-skipping cell
                                        #save tuning width
                                        theta_nonskip_tw.append(tune_width)
                                        theta_nonskip_intrinsic_freq.append(intrinsic_freq)
                                        theta_nonskip_global_freq.append(global_freq)
                                        #save ppp
                                        theta_nonskip_ppp.append(pval)
                                        #save circ-linear correlation
                                        theta_nonskip_clr.append(clr)
                                elif 'HDC' in cell_type:
                                    nontheta_tw.append(tune_width)
                                    nontheta_intrinsic_freq.append(intrinsic_freq)
                                    nontheta_global_freq.append(global_freq)
                                    nontheta_ppp.append(pval)
                                    
                                    nontheta_clr.append(clr)
                                
                                total_hd_cells += 1
                            except Exception as e:
                                print(f"Error processing {cell_name}: {e}")
                        
print(f"Total number of HD cells processed: {total_hd_cells}")
# Out:
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_100919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_250719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_020819_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_240719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_310719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_280819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_210819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_140819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_220819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_31032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09032020_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_11032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_20032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14042020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16032020_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_03042020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_25032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_01042020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10032020_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_12032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13032020_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_19032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_18032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_30032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_22032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_081019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_310719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_040719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_031019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_280619_T1b_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_071019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_110919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_091019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260719_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_101019_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_010719_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_041019_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_110119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_050119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_280219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_130119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120119_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_310119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_010219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070119_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_090219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_290119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_170119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_150219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_140219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_270119_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070219_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_080119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_30032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_17032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_16032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_31032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_11032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_20032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_18032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_01042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_25032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_19032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_22032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_03042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_120319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_060319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_280319_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_130319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_220319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_150319_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_180319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_050319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_170319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_140319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_260319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_080319_T2_sdata.mat
# Total number of HD cells processed: 461

# %% [markdown]
# ## Section 2: get the percentage of HD cells with significant phase precession of turning angle

# %%
# ratio of pval_skip<0.05
# Create arrays for p-values
pval_skip = np.array(theta_skip_ppp)
pval_nonskip = np.array(theta_nonskip_ppp)
pval_nontheta = np.array(nontheta_ppp)

clr_skip = np.array(theta_skip_clr)
clr_nonskip = np.array(theta_nonskip_clr)
clr_nontheta = np.array(nontheta_clr)

# Calculate counts for p-values less than and greater than 0.05
skip_p_less = len(pval_skip[(pval_skip < 0.05) & (clr_skip <0)])
skip_p_more = len(pval_skip) - skip_p_less

nonskip_p_less = len(pval_nonskip[(pval_nonskip < 0.05) & (clr_nonskip <0)])
nonskip_p_more = len(pval_nonskip) - nonskip_p_less

nontheta_p_less = len(pval_nontheta[(pval_nontheta < 0.05) & (clr_nontheta <0)])
nontheta_p_more = len(pval_nontheta) - nontheta_p_less

# Print ratios
print('ratio of pp in theta skipping cells:', skip_p_less / len(pval_skip))
print('ratio of pp in theta non-skipping cells', nonskip_p_less / len(pval_nonskip))
print('ratio of pp in classic HD cells', nontheta_p_less / len(pval_nontheta))

#print the number of cells
print('theta skip cells:', skip_p_less, len(theta_skip_ppp))
print('theta nonskip cells:', nonskip_p_less, len(theta_nonskip_ppp))
print('nontheta HD cells:', nontheta_p_less, len(nontheta_ppp))



# Data for bar plot
categories = ['Non-'+r'$\theta$', r'$\theta$'+'-non-'+'\nskipping', r'$\theta$'+'-'+'\nskipping']
less_than_005 = [nontheta_p_less, nonskip_p_less, skip_p_less]
more_than_005 = [nontheta_p_more, nonskip_p_more, skip_p_more]

# Calculate percentages
total_cells = [nontheta_p_less + nontheta_p_more, nonskip_p_less + nonskip_p_more, skip_p_less + skip_p_more]
percent_less_than_005 = [100 * less / total for less, total in zip(less_than_005, total_cells)]
percent_more_than_005 = [100 * more / total for more, total in zip(more_than_005, total_cells)]

# Create stacked bar plot
fig, ax = plt.subplots(figsize=(2.8, 2.4), dpi=300)

labelsize = 10
ticksize = 8

bar_width = 0.5
bar1 = ax.bar(categories, more_than_005, bar_width, color='grey')
#label ha center, va center
bar2 = ax.bar(categories, less_than_005, bar_width, bottom=more_than_005, label='precession cells', color='#38c7ff')


ax.legend(frameon=False, loc='upper center', fontsize=8, bbox_to_anchor=(0.5, 1.4))

# Add labels and title
ax.set_ylabel('# of Cells', fontsize=labelsize)
#roatte xlabel 45 degree
ax.set_xticklabels(categories, rotation=0, ha='center', fontsize=labelsize, va='center')
#move xlabel closer to the plot
ax.tick_params(axis='x', pad=15)

# Add percentages on top of the higher bars
for i, (less, more, total) in enumerate(zip(less_than_005, more_than_005, total_cells)):
    ax.text(i, more + less + 10, f'{percent_less_than_005[i]:.1f}%', ha='center', va='center', color='black', fontsize=ticksize)

#tickfontsize
ax.tick_params(axis='y', which='major', labelsize=ticksize)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()


plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/phaseprecession_percentage.pdf')
# Out:
# ratio of pp in theta skipping cells: 0.2289156626506024
# ratio of pp in theta non-skipping cells 0.13291139240506328
# ratio of pp in classic HD cells 0.08823529411764706
# theta skip cells: 19 83
# theta nonskip cells: 21 158
# nontheta HD cells: 12 136
# /tmp/ipykernel_3435100/2179884856.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(categories, rotation=0, ha='center', fontsize=labelsize, va='center')

# %% [markdown]
# ## Section 3: get the circular-linear correlation coefficient for three types of HD cells

# %%
#plot clr for nontheta, theta nonskip, theta skip with mean and sem

# Create arrays for circ-linear correlation
clr_nontheta = np.array(nontheta_clr)
clr_theta_nonskip = np.array(theta_nonskip_clr)
clr_theta_skip = np.array(theta_skip_clr)

fig, ax = plt.subplots(figsize=(2.6, 1.8), dpi=300)

# Plot the mean and standard error of the circ-linear correlation
mean_clr_nontheta = np.mean(clr_nontheta)
sem_clr_nontheta = np.std(clr_nontheta) / np.sqrt(len(clr_nontheta))
mean_clr_theta_nonskip = np.mean(clr_theta_nonskip)
sem_clr_theta_nonskip = np.std(clr_theta_nonskip) / np.sqrt(len(clr_theta_nonskip))
mean_clr_theta_skip = np.mean(clr_theta_skip)
sem_clr_theta_skip = np.std(clr_theta_skip) / np.sqrt(len(clr_theta_skip))

# Plot the bars
bar_width = 0.5
bar1 = ax.bar(['Non-theta', 'Theta-non-'+'\nskipping', 'Theta-\nskipping'], [mean_clr_nontheta, mean_clr_theta_nonskip, mean_clr_theta_skip], bar_width, yerr=[sem_clr_nontheta, sem_clr_theta_nonskip, sem_clr_theta_skip], capsize=3, color='grey')

#add y=0
ax.axhline(y=0, color='red', linestyle='--', linewidth=1.0)

#ylim
ax.set_ylim(-0.05, 0.02)
ax.set_yticks([-0.04, -0.02, 0, 0.02])

# Add labels and title
ax.set_ylabel('C-L corr. coef.', fontsize=labelsize)
#roatte xlabel 45 degree
ax.set_xticklabels(['Non-'+r'$\theta$', r'$\theta$'+'-non-'+'\nskipping', r'$\theta$'+'-'+'\nskipping'], rotation=0, ha='center', fontsize=labelsize-0.5, va='center')
#move xlabel closer to the plot
ax.tick_params(axis='x', pad=15)

# #y ticks in scientific notation
# ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))

#tickfontsize
ax.tick_params(axis='y', which='major', labelsize=ticksize)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#mannwhitneyu test between nontheta and theta nonskip
_, pval = mannwhitneyu(clr_nontheta, clr_theta_nonskip)
print('pval between nontheta and theta nonskip:', pval)

#mannwhitneyu test between nontheta and theta skip
_, pval = mannwhitneyu(clr_nontheta, clr_theta_skip)
print('pval between nontheta and theta skip:', pval)

#mannwhitneyu test between theta nonskip and theta skip
_, pval = mannwhitneyu(clr_theta_nonskip, clr_theta_skip)
print('pval between theta nonskip and theta skip:', pval)

plt.tight_layout()

plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/clr_coefficient_in_three_celltypes.pdf')
# Out:
# pval between nontheta and theta nonskip: 0.01119856211669787
# pval between nontheta and theta skip: 0.03974079379512625
# pval between theta nonskip and theta skip: 0.9713031996077292
# /tmp/ipykernel_3435100/2077516719.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Non-'+r'$\theta$', r'$\theta$'+'-non-'+'\nskipping', r'$\theta$'+'-'+'\nskipping'], rotation=0, ha='center', fontsize=labelsize-0.5, va='center')

# %% [markdown]
# ## Section 4: plot the intrinsic frequency against global frequency for three types of HD cells. Note that I delete cells with global freqeuncy hit the 7 HZ or 12 Hz boundary (I guess fitting failed in this case).

# %%
fig, axs = plt.subplots(1,3, figsize=(8, 3), dpi=300)

ax = axs[0]
#plot intrinsic freq against global freq for nontheta cells
#remove nontheta_global_freq when it is < 7.2
nontheta_global_freq = np.array(nontheta_global_freq)
nontheta_intrinsic_freq = np.array(nontheta_intrinsic_freq)
indx = np.where((nontheta_global_freq >= 7.2) & (nontheta_global_freq <=11.8))
ax.scatter(nontheta_global_freq[indx], 
           nontheta_intrinsic_freq[indx], 
           color='#009FB9', label='Non-theta', s=5)
ax.set_title('Non-theta cells', fontsize=labelsize)

ax = axs[1]
#plot intrinsic freq against global freq for theta nonskip cells
theta_nonskip_global_freq = np.array(theta_nonskip_global_freq)
theta_nonskip_intrinsic_freq = np.array(theta_nonskip_intrinsic_freq)
indx = np.where((theta_nonskip_global_freq >= 7.2) & (theta_nonskip_global_freq <=11.8))
ax.scatter(theta_nonskip_global_freq[indx], 
           theta_nonskip_intrinsic_freq[indx], 
           color='#009FB9', label='Theta-non-skip', s=5)
ax.set_title('Theta-non-skip cells', fontsize=labelsize)

ax = axs[2]
#plot intrinsic freq against global freq for theta skip cells
theta_skip_global_freq = np.array(theta_skip_global_freq)
theta_skip_intrinsic_freq = np.array(theta_skip_intrinsic_freq)
indx = np.where((theta_skip_global_freq >= 7.2) & (theta_skip_global_freq <=11.8))
ax.scatter(theta_skip_global_freq[indx], theta_skip_intrinsic_freq[indx], color='#009FB9', label='Theta-skip', s=5)
ax.set_title('Theta-skip cells', fontsize=labelsize)

for ax in axs:
    ax.set_xlim(7, 12)
    ax.set_ylim(7, 12)
    #equal aspect ratio
    ax.set_aspect('equal', 'box')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    #add y=x line
    ax.plot([2, 13], [2, 13], color='grey', linestyle='--', linewidth=1.0)
    #x label
    ax.set_xlabel('Global frequency (Hz)', fontsize=labelsize)
    #y label
    ax.set_ylabel('Intrinsic frequency (Hz)', fontsize=labelsize)

plt.tight_layout()

# %% [markdown]
# ## Section 4.2: plot intrinsic freq vs global freq specifically for significant phase precession cells

# %%
fig, axs = plt.subplots(1,3, figsize=(8, 3), dpi=300)

ax = axs[0]
#plot intrinsic freq against global freq for nontheta cells
#filter p < 0.05 and clr < 0 for nontheta_global_freq and nontheta_intrinsic_freq
indx = np.where((np.array(nontheta_ppp) < 0.05) 
                & (np.array(nontheta_clr) < 0)
                & (np.array(nontheta_global_freq) >= 7.2)
                & (np.array(nontheta_global_freq) <= 11.8))[0]
ax.scatter(np.array(nontheta_global_freq)[indx], 
           np.array(nontheta_intrinsic_freq)[indx], 
           color='red', label='Non-theta', s=5)
ax.set_title('Non-theta cells', fontsize=labelsize)

ax = axs[1]
#plot intrinsic freq against global freq for theta nonskip cells
#filter p < 0.05 for theta_nonskip_global_freq and theta_nonskip_intrinsic_freq
indx = np.where((np.array(theta_nonskip_ppp) < 0.05) 
                & (np.array(theta_nonskip_clr) < 0)
                & (np.array(theta_nonskip_global_freq) >= 7.2)
                & (np.array(theta_nonskip_global_freq) <= 11.8))[0]
ax.scatter(np.array(theta_nonskip_global_freq)[indx], 
           np.array(theta_nonskip_intrinsic_freq)[indx], 
           color='red', label='Theta-non-skip', s=5)
ax.set_title('Theta-non-skip cells', fontsize=labelsize)

ax = axs[2]
#plot intrinsic freq against global freq for theta skip cells
#filter p < 0.05 for theta_skip_global_freq and theta_skip_intrinsic_freq
indx = np.where((np.array(theta_skip_ppp) < 0.05) 
                & (np.array(theta_skip_clr) < 0)
                & (np.array(theta_skip_global_freq) >= 7.2)
                & (np.array(theta_skip_global_freq) <= 11.8))[0]
ax.scatter(np.array(theta_skip_global_freq)[indx], 
           np.array(theta_skip_intrinsic_freq)[indx], 
           color='red', label='Theta-skip', s=5)
ax.set_title('Theta-skip cells', fontsize=labelsize)

for ax in axs:
    ax.set_xlim(8, 10)
    ax.set_ylim(8, 10)
    #equal aspect ratio
    ax.set_aspect('equal', 'box')
    #add y=x line
    ax.plot([6, 12], [6, 12], color='grey', linestyle='--', linewidth=1.0)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### merge all pp cells together

# %%
fig, ax = plt.subplots(figsize=(2.8, 2.4), dpi=300)

#filter theta_intrinsic_freq and theta_global_freq by their p < 0.05 and clr < 0

indx_pp = np.where((np.array(theta_ppp) < 0.05) 
                    & (np.array(theta_clr) < 0)
                    & (np.array(theta_global_freq) >= 7.2)
                    & (np.array(theta_global_freq) <= 11.8))[0]

#for cells with theta_ppp > 0.05, global freq > 7.2 and global freq < 11.8
indx_nonpp1 = np.where((np.array(theta_ppp) > 0.05)
                    & (np.array(theta_global_freq) >= 7.2)
                    & (np.array(theta_global_freq) <= 11.8))[0]
#or cells with theta_ppp < 0.05 & theta_clr >=0 and global freq > 7.2 and global freq < 11.8
indx_nonpp2 = np.where((np.array(theta_ppp) < 0.05)
                    & (np.array(theta_clr) >= 0)
                    & (np.array(theta_global_freq) >= 7.2)
                    & (np.array(theta_global_freq) <= 11.8))[0]
#combine them
indx_nonpp = np.concatenate((indx_nonpp1, indx_nonpp2)) 


ax.scatter(np.array(theta_global_freq)[indx_nonpp],
           np.array(theta_intrinsic_freq)[indx_nonpp],
           color='#F18D00', label='non-precession cells', s=20, alpha=0.5, edgecolors='none')

ax.scatter(np.array(theta_global_freq)[indx_pp],
           np.array(theta_intrinsic_freq)[indx_pp],
           color='#009FB9', label='precession cells', s=20, alpha=0.8, edgecolors='none')

ax.legend(frameon=False, loc='upper center', fontsize=8, ncol=1, bbox_to_anchor=(0.5, 1.3))

#add y=x
ax.plot([8, 10], [8, 10], color='red', linestyle='--', linewidth=1.0)

ax.set_xlim(8, 10)
ax.set_ylim(8, 10)
ax.set_xlabel('Global freq (Hz)', fontsize=labelsize)
ax.set_ylabel('Intr. freq (Hz)', fontsize=labelsize)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='x', which='major', labelsize=ticksize)
ax.tick_params(axis='y', which='major', labelsize=ticksize)

plt.tight_layout()

plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/intrinsic_vs_global_freq.pdf')


fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)
#do a histogram plot of the difference between global freq - intrinsic freq
diff = np.array(theta_global_freq) - np.array(theta_intrinsic_freq)

diff_nonpp = diff[indx_nonpp]
bins = np.linspace(-2, 2, 40)
ax.hist(diff_nonpp, bins=bins, color='#F18D00', edgecolor='black', linewidth=0.2, alpha=0.8, density=True, label='non-precession cells')


diff_pp = diff[indx_pp]
bins = np.linspace(-1, 1, 20)
#throw away the outliers if np.abs(diff_pp)>4
ax.hist(diff_pp, bins=bins, color='#009FB9', edgecolor='black', linewidth=0.2, alpha=0.8, density=True, label='precession cells')

ax.legend(frameon=False, loc='upper center', fontsize=8, ncol=1, bbox_to_anchor=(0.5, 1.3))

#x=0
ax.axvline(x=0, color='red', linestyle='--', linewidth=1.0)

ax.set_xlabel('Global - Intr. freq. (Hz)', fontsize=labelsize)
ax.set_ylabel('Prob. density', fontsize=labelsize)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#tick size
ax.tick_params(axis='x', which='major', labelsize=ticksize)
ax.tick_params(axis='y', which='major', labelsize=ticksize)

#compare diff_nonpp and diff_pp using mannwhitneyu test
_, pval = mannwhitneyu(diff_nonpp, diff_pp)
print('pval between nonpp and pp:', pval)

#diff_nonpp againt 0 using wilcoxon signed rank test
_, pval = wilcoxon(diff_nonpp)
print('pval between nonpp and 0:', pval)

#diff_pp againt 0 using wilcoxon signed rank test
_, pval = wilcoxon(diff_pp)
print('pval between pp and 0:', pval)

plt.tight_layout()

plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/global_vs_intrinsic_freq_histogram.pdf')
# Out:
# pval between nonpp and pp: 0.04908179322587179
# pval between nonpp and 0: 0.0012081333337315163
# pval between pp and 0: 8.272974810097367e-05

# %% [markdown]
# ## Section 4.3: check the degree of phase precession against intrinsic frequency

# %%
#plot intrinsic frequency against circ-linear correlation for all cells

fig, axs = plt.subplots(1,2,figsize=(6, 2.5), dpi=300)

ax = axs[0]
#plot intrinsic freq against circ-linear correlation for all cells
ax.scatter(all_intrinsic_freq, all_clr, color='red', label='All', s=1)

ax = axs[1]
#do this only for theta_ppp<0.05 and clr<0
indx = np.where((np.array(all_ppp) < 0.05) 
                & (np.array(all_clr) < 0)
                & (np.array(all_global_freq) >= 7.2)
                & (np.array(all_global_freq) <= 11.8))[0]

ax.scatter(np.array(all_intrinsic_freq)[indx]-np.array(all_global_freq)[indx], np.array(all_clr)[indx], color='red', label='All', s=1)

#correlation test between np.array(all_intrinsic_freq)[indx] and np.array(all_clr)[indx]

from scipy.stats import spearmanr
r, p = spearmanr(np.array(all_intrinsic_freq)[indx], np.array(all_clr)[indx])
print('r:', r, 'p:', p)

for ax in axs:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xlabel('Intrinsic Freq. (Hz)', fontsize=labelsize)
    ax.set_ylabel('C-L corr. coef.', fontsize=labelsize)
    
plt.tight_layout()
# Out:
# r: -0.17828054298642532 p: 0.21069010888937534

# %% [markdown]
# ## Section 5: demonstration of sin wave fitting to the autocorrelogram of spike train

# %%
fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)

ax = plot_autocorrelogram(ax, autocorrelogram)
plt.tight_layout()

plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/autocorrelogram.pdf')
# Out:
# Intrinsic Theta Frequency: 8.40 Hz

# %%
base_dir = '/home/zilong/Desktop/HDPhasePrecession/LomiData'
output_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/autocorrrelogram/all/'
output_skip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/autocorrrelogram/skip/'
output_nonskip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/autocorrrelogram/nonskip/'
output_nontheta_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/autocorrrelogram/nontheta/'

# Configuration
config = {
    'hd_bins': 60,
    'hd_boxcar': 3,
    'speed_threshold': 0.5,
    'duration_threshold': 0.5,
    'speed_smooth_sigma': 40,  #0.8,0.8,40 gives 43% pp cells
    'movingdirection_sigma': 5, #time bin size 20 ms, so 5 is 100 ms
    'interpolation_factor': 1, #1 is 0.02s, and 2 is 0.01s
    'IFR_window':0.2
}

# Create output directories if they don't exist
for dir_path in [output_dir, output_skip_dir, output_nonskip_dir, output_nontheta_dir]:
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)    
    os.makedirs(dir_path)

total_hd_cells = 0

matnames = {}

# Iterate through each subfolder in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    if os.path.isdir(subdir_path):
        # Iterate through each .mat file in the subfolder
        for file in os.listdir(subdir_path):
            if file.endswith('_sdata.mat'):
                file_path = os.path.join(subdir_path, file)
                print(f"Processing {file_path}")
                ratname = file.split('_')[0]
                data_dict = HD_utils.load_data(ratname, file_path)
                
                if data_dict is not None:
                    ppoh = data_dict['poh']
                    pot = data_dict['pot'].flatten()
                    
                    ppox = data_dict['ppox'].flatten()
                    ppoy = data_dict['ppoy'].flatten()
                    global_freq = data_dict['global_freq'][0][0]
                    
                    #interpolte pot 
                    sampling_interval = np.diff(pot).mean()
                    new_interval = sampling_interval / config['interpolation_factor']
                    pot_interp = np.arange(0, pot[-1], new_interval)
                    
                    for cell_name, cell_data in data_dict['cells_data'].items():
                        psph = cell_data['psph'].flatten()
                        pspt = cell_data['pspt'].flatten()
                        spike_phase = cell_data['spike_phase'].flatten()
                        hd_pval = cell_data['pval'][0][0]
                        hd_mean = cell_data['hd_mean'][0][0]
                        hd_std = cell_data['hd_std'][0][0]
                        tune_width = cell_data['tune_width'][0][0]
                        autocorrelogram = cell_data['autocorrelogram']
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        hd_rayleigh = cell_data['hd_rayleigh'][0][0]
                        hd_rayleigh_shuffle_99 = cell_data['hd_rayleigh_shuffle_99'][0][0]
                        peak_fr = cell_data['peak_fr'][0][0]
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        cell_type = cell_data['cell_type']
                        
                        #store matname for each cell
                        matnames[cell_name] = [ratname, file_path]
                        
                        #if hd_pval < 0.05: #select only head direction tuned cells
                        if hd_rayleigh > hd_rayleigh_shuffle_99 and peak_fr > 1: #select only head direction tuned cells with rayleigh vector > 99% shuffle and the peak firing rate in the directional field is greater than 1 Hz
                            try:
                                fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)
                                ax, intrinsic_frequency = plot_autocorrelogram(ax, autocorrelogram)
                                
                                output_path = os.path.join(output_dir, f"{cell_name}--{np.round(intrinsic_frequency, 2)}Hz.pdf")
                                
                                plt.tight_layout()
                                plt.savefig(output_path)
                            
                                #save fig according to cell type in different folders
                                if 'Strong ThetaxHD' in cell_type: #This is a theta modulated HD cell
 
                                    if 'skip'in cell_type: #this is a theta skipping cell
                                        output_skip_path = os.path.join(output_skip_dir, f"{cell_name}--{np.round(intrinsic_frequency, 2)}Hz.pdf")
                                        plt.savefig(output_skip_path)
                                    elif 'Strong ThetaxHD' in cell_type: #this is a theta modulated non-skipping cell
                                        output_nonskip_path = os.path.join(output_nonskip_dir, f"{cell_name}--{np.round(intrinsic_frequency, 2)}Hz.pdf")
                                        plt.savefig(output_nonskip_path)
                                elif 'HDC' in cell_type:
                                    output_nontheta_path = os.path.join(output_nontheta_dir, f"{cell_name}--{np.round(intrinsic_frequency, 2)}Hz.pdf")
                                    plt.savefig(output_nontheta_path)
                                    
                                plt.close(fig)
                                total_hd_cells += 1
                            except Exception as e:
                                plt.close(fig)
                                print(f"Error processing {cell_name}: {e}")
                        
print(f"Total number of HD cells processed: {total_hd_cells}")
# Out:
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_100919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.83 Hz
# Intrinsic Theta Frequency: 7.39 Hz
# Intrinsic Theta Frequency: 8.64 Hz
# Intrinsic Theta Frequency: 8.62 Hz
# Intrinsic Theta Frequency: 8.64 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_250719_T1_sdata.mat
# Intrinsic Theta Frequency: 9.42 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090819_T1_sdata.mat
# Intrinsic Theta Frequency: 10.84 Hz
# Intrinsic Theta Frequency: 9.55 Hz
# Intrinsic Theta Frequency: 9.65 Hz
# Intrinsic Theta Frequency: 9.62 Hz
# Intrinsic Theta Frequency: 10.64 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_230819_T1_sdata.mat
# Intrinsic Theta Frequency: 10.61 Hz
# Intrinsic Theta Frequency: 8.74 Hz
# Intrinsic Theta Frequency: 8.04 Hz
# Intrinsic Theta Frequency: 7.96 Hz
# Intrinsic Theta Frequency: 8.73 Hz
# Intrinsic Theta Frequency: 8.62 Hz
# Intrinsic Theta Frequency: 8.65 Hz
# Intrinsic Theta Frequency: 8.67 Hz
# Intrinsic Theta Frequency: 8.75 Hz
# Intrinsic Theta Frequency: 8.67 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.33 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 7.67 Hz
# Intrinsic Theta Frequency: 8.71 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_150819_T1_sdata.mat
# Intrinsic Theta Frequency: 9.12 Hz
# Intrinsic Theta Frequency: 8.64 Hz
# Intrinsic Theta Frequency: 8.00 Hz
# Intrinsic Theta Frequency: 7.64 Hz
# Intrinsic Theta Frequency: 8.17 Hz
# Intrinsic Theta Frequency: 8.94 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_290719_T3_sdata.mat
# Intrinsic Theta Frequency: 9.66 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.01 Hz
# Intrinsic Theta Frequency: 9.13 Hz
# Intrinsic Theta Frequency: 7.32 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.48 Hz
# Intrinsic Theta Frequency: 8.79 Hz
# Intrinsic Theta Frequency: 9.75 Hz
# Intrinsic Theta Frequency: 8.65 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_020819_T3_sdata.mat
# Intrinsic Theta Frequency: 9.60 Hz
# Intrinsic Theta Frequency: 9.55 Hz
# Intrinsic Theta Frequency: 8.57 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120819_T2_sdata.mat
# Intrinsic Theta Frequency: 9.28 Hz
# Intrinsic Theta Frequency: 8.29 Hz
# Intrinsic Theta Frequency: 8.01 Hz
# Intrinsic Theta Frequency: 7.38 Hz
# Intrinsic Theta Frequency: 9.33 Hz
# Intrinsic Theta Frequency: 8.64 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_240719_T2_sdata.mat
# Intrinsic Theta Frequency: 9.18 Hz
# Intrinsic Theta Frequency: 9.13 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.67 Hz
# Intrinsic Theta Frequency: 9.91 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_310719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.65 Hz
# Intrinsic Theta Frequency: 8.25 Hz
# Intrinsic Theta Frequency: 9.14 Hz
# Intrinsic Theta Frequency: 8.61 Hz
# Intrinsic Theta Frequency: 6.00 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.04 Hz
# Intrinsic Theta Frequency: 7.96 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_130819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.68 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Intrinsic Theta Frequency: 8.37 Hz
# Intrinsic Theta Frequency: 10.61 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_280819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 7.83 Hz
# Intrinsic Theta Frequency: 8.55 Hz
# Intrinsic Theta Frequency: 8.72 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.44 Hz
# Intrinsic Theta Frequency: 8.39 Hz
# Intrinsic Theta Frequency: 8.45 Hz
# Intrinsic Theta Frequency: 10.17 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.99 Hz
# Intrinsic Theta Frequency: 9.19 Hz
# Intrinsic Theta Frequency: 8.62 Hz
# Intrinsic Theta Frequency: 8.80 Hz
# Intrinsic Theta Frequency: 8.79 Hz
# Intrinsic Theta Frequency: 8.55 Hz
# Intrinsic Theta Frequency: 8.37 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.73 Hz
# Intrinsic Theta Frequency: 10.23 Hz
# Intrinsic Theta Frequency: 8.74 Hz
# Intrinsic Theta Frequency: 12.00 Hz
# Intrinsic Theta Frequency: 7.98 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.68 Hz
# Intrinsic Theta Frequency: 8.69 Hz
# Intrinsic Theta Frequency: 8.81 Hz
# Intrinsic Theta Frequency: 8.53 Hz
# Intrinsic Theta Frequency: 6.08 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_210819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.63 Hz
# Intrinsic Theta Frequency: 9.42 Hz
# Intrinsic Theta Frequency: 8.74 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.63 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_080819_T1_sdata.mat
# Intrinsic Theta Frequency: 11.28 Hz
# Intrinsic Theta Frequency: 10.23 Hz
# Intrinsic Theta Frequency: 7.79 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.55 Hz
# Intrinsic Theta Frequency: 8.40 Hz
# Intrinsic Theta Frequency: 9.35 Hz
# Intrinsic Theta Frequency: 10.02 Hz
# Intrinsic Theta Frequency: 8.58 Hz
# Intrinsic Theta Frequency: 8.68 Hz
# Intrinsic Theta Frequency: 8.75 Hz
# Intrinsic Theta Frequency: 8.66 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_140819_T1_sdata.mat
# Intrinsic Theta Frequency: 9.36 Hz
# Intrinsic Theta Frequency: 10.24 Hz
# Intrinsic Theta Frequency: 8.56 Hz
# Intrinsic Theta Frequency: 9.23 Hz
# Intrinsic Theta Frequency: 7.92 Hz
# Intrinsic Theta Frequency: 6.65 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_220819_T1_sdata.mat
# Intrinsic Theta Frequency: 7.65 Hz
# Intrinsic Theta Frequency: 8.71 Hz
# Intrinsic Theta Frequency: 9.02 Hz
# Intrinsic Theta Frequency: 8.64 Hz
# Intrinsic Theta Frequency: 8.55 Hz
# Intrinsic Theta Frequency: 8.38 Hz
# Intrinsic Theta Frequency: 8.11 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 8.96 Hz
# Intrinsic Theta Frequency: 8.16 Hz
# Intrinsic Theta Frequency: 9.80 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.98 Hz
# Intrinsic Theta Frequency: 8.36 Hz
# Intrinsic Theta Frequency: 8.71 Hz
# Intrinsic Theta Frequency: 9.33 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Intrinsic Theta Frequency: 8.67 Hz
# Intrinsic Theta Frequency: 8.62 Hz
# Intrinsic Theta Frequency: 7.82 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.62 Hz
# Intrinsic Theta Frequency: 9.53 Hz
# Intrinsic Theta Frequency: 9.96 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_31032020_T2_sdata.mat
# Intrinsic Theta Frequency: 8.92 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09032020_T4_sdata.mat
# Intrinsic Theta Frequency: 8.57 Hz
# Intrinsic Theta Frequency: 8.48 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_23032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.14 Hz
# Intrinsic Theta Frequency: 9.38 Hz
# Intrinsic Theta Frequency: 8.12 Hz
# Intrinsic Theta Frequency: 9.21 Hz
# Intrinsic Theta Frequency: 8.02 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10042020_T1_sdata.mat
# Intrinsic Theta Frequency: 10.46 Hz
# Intrinsic Theta Frequency: 9.14 Hz
# Intrinsic Theta Frequency: 8.13 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_11032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 8.87 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_20032020_T3_sdata.mat
# Intrinsic Theta Frequency: 8.88 Hz
# Intrinsic Theta Frequency: 8.83 Hz
# Intrinsic Theta Frequency: 9.64 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14042020_T2_sdata.mat
# Intrinsic Theta Frequency: 8.85 Hz
# Intrinsic Theta Frequency: 7.86 Hz
# Intrinsic Theta Frequency: 7.61 Hz
# Intrinsic Theta Frequency: 10.81 Hz
# Intrinsic Theta Frequency: 8.79 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_24032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.95 Hz
# Intrinsic Theta Frequency: 10.05 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16032020_T4_sdata.mat
# Intrinsic Theta Frequency: 8.31 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_03042020_T3_sdata.mat
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 9.82 Hz
# Intrinsic Theta Frequency: 9.24 Hz
# Intrinsic Theta Frequency: 8.65 Hz
# Intrinsic Theta Frequency: 9.82 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_06042020_T1_sdata.mat
# Intrinsic Theta Frequency: 7.43 Hz
# Intrinsic Theta Frequency: 8.15 Hz
# Intrinsic Theta Frequency: 8.72 Hz
# Error processing rR448_06042020_t2_c2: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Intrinsic Theta Frequency: 8.84 Hz
# Error processing rR448_06042020_t4_c1: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15042020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.94 Hz
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 9.25 Hz
# Intrinsic Theta Frequency: 8.73 Hz
# Intrinsic Theta Frequency: 8.72 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_25032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.67 Hz
# Intrinsic Theta Frequency: 9.10 Hz
# Intrinsic Theta Frequency: 9.10 Hz
# Intrinsic Theta Frequency: 9.16 Hz
# Intrinsic Theta Frequency: 9.14 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_01042020_T2_sdata.mat
# Intrinsic Theta Frequency: 9.04 Hz
# Intrinsic Theta Frequency: 9.05 Hz
# Intrinsic Theta Frequency: 9.06 Hz
# Intrinsic Theta Frequency: 7.91 Hz
# Intrinsic Theta Frequency: 8.96 Hz
# Intrinsic Theta Frequency: 9.11 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16042020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.21 Hz
# Intrinsic Theta Frequency: 8.18 Hz
# Intrinsic Theta Frequency: 10.36 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09042020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.58 Hz
# Intrinsic Theta Frequency: 7.62 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_07042020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.88 Hz
# Intrinsic Theta Frequency: 9.14 Hz
# Intrinsic Theta Frequency: 10.87 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 7.76 Hz
# Intrinsic Theta Frequency: 9.15 Hz
# Intrinsic Theta Frequency: 9.17 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10032020_T5_sdata.mat
# Intrinsic Theta Frequency: 8.96 Hz
# Intrinsic Theta Frequency: 8.94 Hz
# Intrinsic Theta Frequency: 9.01 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_12032020_T3_sdata.mat
# Intrinsic Theta Frequency: 8.91 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_08042020_T1_sdata.mat
# Intrinsic Theta Frequency: 7.65 Hz
# Intrinsic Theta Frequency: 9.69 Hz
# Intrinsic Theta Frequency: 8.94 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_26032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.74 Hz
# Intrinsic Theta Frequency: 9.11 Hz
# Intrinsic Theta Frequency: 8.47 Hz
# Intrinsic Theta Frequency: 9.07 Hz
# Intrinsic Theta Frequency: 8.72 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13042020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.43 Hz
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 8.49 Hz
# Intrinsic Theta Frequency: 9.48 Hz
# Intrinsic Theta Frequency: 9.19 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Intrinsic Theta Frequency: 8.60 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.30 Hz
# Intrinsic Theta Frequency: 9.42 Hz
# Intrinsic Theta Frequency: 9.04 Hz
# Intrinsic Theta Frequency: 9.57 Hz
# Intrinsic Theta Frequency: 9.50 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13032020_T8_sdata.mat
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 8.09 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_19032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.68 Hz
# Intrinsic Theta Frequency: 8.47 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_18032020_T2_sdata.mat
# Intrinsic Theta Frequency: 9.33 Hz
# Intrinsic Theta Frequency: 8.92 Hz
# Intrinsic Theta Frequency: 8.74 Hz
# Intrinsic Theta Frequency: 9.34 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_30032020_T3_sdata.mat
# Intrinsic Theta Frequency: 8.76 Hz
# Intrinsic Theta Frequency: 8.95 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_22032020_T2_sdata.mat
# Intrinsic Theta Frequency: 9.42 Hz
# Intrinsic Theta Frequency: 8.95 Hz
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 8.48 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.23 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 8.82 Hz
# Intrinsic Theta Frequency: 9.06 Hz
# Intrinsic Theta Frequency: 9.20 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_081019_T1_sdata.mat
# Intrinsic Theta Frequency: 9.16 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_310719_T1_sdata.mat
# Intrinsic Theta Frequency: 8.73 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_040719_T1_sdata.mat
# Intrinsic Theta Frequency: 9.41 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.95 Hz
# Intrinsic Theta Frequency: 8.10 Hz
# Intrinsic Theta Frequency: 9.10 Hz
# Intrinsic Theta Frequency: 8.67 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.91 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_031019_T1_sdata.mat
# Intrinsic Theta Frequency: 8.61 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_280619_T1b_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 8.92 Hz
# Intrinsic Theta Frequency: 8.13 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080719_T1_sdata.mat
# Intrinsic Theta Frequency: 8.86 Hz
# Intrinsic Theta Frequency: 9.08 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 8.68 Hz
# Intrinsic Theta Frequency: 8.80 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.99 Hz
# Intrinsic Theta Frequency: 9.07 Hz
# Intrinsic Theta Frequency: 9.15 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_071019_T1_sdata.mat
# Intrinsic Theta Frequency: 8.60 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_110919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.93 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.07 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.71 Hz
# Intrinsic Theta Frequency: 8.55 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_091019_T1_sdata.mat
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 9.17 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_120919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.78 Hz
# Intrinsic Theta Frequency: 8.76 Hz
# Intrinsic Theta Frequency: 8.79 Hz
# Intrinsic Theta Frequency: 8.82 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090819_T1_sdata.mat
# Intrinsic Theta Frequency: 9.00 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260719_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_170919_T1_sdata.mat
# Intrinsic Theta Frequency: 8.72 Hz
# Intrinsic Theta Frequency: 8.89 Hz
# Intrinsic Theta Frequency: 8.79 Hz
# Intrinsic Theta Frequency: 8.65 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260819_T1_sdata.mat
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_030919_T1_sdata.mat
# Intrinsic Theta Frequency: 10.53 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_101019_T2_sdata.mat
# Intrinsic Theta Frequency: 7.05 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_010719_T7_sdata.mat
# Intrinsic Theta Frequency: 9.43 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090919_T1_sdata.mat
# Intrinsic Theta Frequency: 9.01 Hz
# Intrinsic Theta Frequency: 8.82 Hz
# Intrinsic Theta Frequency: 8.62 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260619_T1_sdata.mat
# Intrinsic Theta Frequency: 9.02 Hz
# Intrinsic Theta Frequency: 8.93 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_041019_T2_sdata.mat
# Intrinsic Theta Frequency: 8.92 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080819_T1_sdata.mat
# Intrinsic Theta Frequency: 9.33 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_110119_T4_sdata.mat
# Intrinsic Theta Frequency: 8.77 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030119_T4_sdata.mat
# Intrinsic Theta Frequency: 8.28 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_050119_T2_sdata.mat
# Intrinsic Theta Frequency: 10.64 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_280219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160119_T4_sdata.mat
# Intrinsic Theta Frequency: 8.44 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_130119_T2_sdata.mat
# Intrinsic Theta Frequency: 8.76 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190219_T2_sdata.mat
# Intrinsic Theta Frequency: 8.78 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120119_T6_sdata.mat
# Intrinsic Theta Frequency: 10.31 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220219_T2_sdata.mat
# Intrinsic Theta Frequency: 8.30 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_310119_T4_sdata.mat
# Intrinsic Theta Frequency: 8.32 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_010219_T2_sdata.mat
# Intrinsic Theta Frequency: 8.47 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070119_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190119_T1_sdata.mat
# Intrinsic Theta Frequency: 7.79 Hz
# Intrinsic Theta Frequency: 8.41 Hz
# Intrinsic Theta Frequency: 7.50 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T2_sdata.mat
# Intrinsic Theta Frequency: 8.51 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_090219_T1_sdata.mat
# Intrinsic Theta Frequency: 8.11 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_290119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_170119_T8_sdata.mat
# Intrinsic Theta Frequency: 8.69 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_150219_T1_sdata.mat
# Intrinsic Theta Frequency: 8.64 Hz
# Intrinsic Theta Frequency: 8.41 Hz
# Intrinsic Theta Frequency: 9.38 Hz
# Intrinsic Theta Frequency: 8.24 Hz
# Intrinsic Theta Frequency: 8.19 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_140219_T4_sdata.mat
# Intrinsic Theta Frequency: 8.03 Hz
# Intrinsic Theta Frequency: 8.17 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_270119_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120219_T1_sdata.mat
# Intrinsic Theta Frequency: 8.62 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T5_sdata.mat
# Intrinsic Theta Frequency: 8.89 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070219_T5_sdata.mat
# Intrinsic Theta Frequency: 8.40 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_080119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_27032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.92 Hz
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 8.78 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 9.16 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 9.33 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_26032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.62 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 9.14 Hz
# Intrinsic Theta Frequency: 9.64 Hz
# Intrinsic Theta Frequency: 9.21 Hz
# Intrinsic Theta Frequency: 8.96 Hz
# Intrinsic Theta Frequency: 9.00 Hz
# Intrinsic Theta Frequency: 9.53 Hz
# Intrinsic Theta Frequency: 9.25 Hz
# Intrinsic Theta Frequency: 9.37 Hz
# Intrinsic Theta Frequency: 9.02 Hz
# Intrinsic Theta Frequency: 8.61 Hz
# Intrinsic Theta Frequency: 8.67 Hz
# Intrinsic Theta Frequency: 8.39 Hz
# Intrinsic Theta Frequency: 9.88 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_30032020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.17 Hz
# Intrinsic Theta Frequency: 8.77 Hz
# Intrinsic Theta Frequency: 8.57 Hz
# Intrinsic Theta Frequency: 8.53 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.95 Hz
# Intrinsic Theta Frequency: 9.06 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_07042020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.39 Hz
# Intrinsic Theta Frequency: 9.53 Hz
# Intrinsic Theta Frequency: 8.69 Hz
# Intrinsic Theta Frequency: 8.91 Hz
# Intrinsic Theta Frequency: 9.20 Hz
# Intrinsic Theta Frequency: 9.02 Hz
# Intrinsic Theta Frequency: 9.13 Hz
# Intrinsic Theta Frequency: 9.10 Hz
# Intrinsic Theta Frequency: 8.84 Hz
# Intrinsic Theta Frequency: 9.30 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_17032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.58 Hz
# Intrinsic Theta Frequency: 8.96 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10042020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.43 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Intrinsic Theta Frequency: 9.17 Hz
# Intrinsic Theta Frequency: 8.82 Hz
# Intrinsic Theta Frequency: 9.39 Hz
# Intrinsic Theta Frequency: 9.03 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_16032020_T2_sdata.mat
# Intrinsic Theta Frequency: 9.27 Hz
# Intrinsic Theta Frequency: 9.70 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_31032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.70 Hz
# Intrinsic Theta Frequency: 8.90 Hz
# Intrinsic Theta Frequency: 8.88 Hz
# Intrinsic Theta Frequency: 8.63 Hz
# Intrinsic Theta Frequency: 9.23 Hz
# Intrinsic Theta Frequency: 9.01 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_11032020_T2_sdata.mat
# Intrinsic Theta Frequency: 8.88 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_20032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.87 Hz
# Intrinsic Theta Frequency: 9.12 Hz
# Intrinsic Theta Frequency: 9.49 Hz
# Intrinsic Theta Frequency: 9.39 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_24032020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.59 Hz
# Intrinsic Theta Frequency: 9.27 Hz
# Intrinsic Theta Frequency: 8.85 Hz
# Intrinsic Theta Frequency: 8.97 Hz
# Intrinsic Theta Frequency: 9.05 Hz
# Intrinsic Theta Frequency: 8.98 Hz
# Intrinsic Theta Frequency: 8.75 Hz
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_02042020_T1_sdata.mat
# Intrinsic Theta Frequency: 8.53 Hz
# Intrinsic Theta Frequency: 9.54 Hz
# Intrinsic Theta Frequency: 8.88 Hz
# Intrinsic Theta Frequency: 9.13 Hz
# Intrinsic Theta Frequency: 9.00 Hz
# Error processing rR449_02042020_t4_c4: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_09042020_T1_sdata.mat
# Intrinsic Theta Frequency: 9.20 Hz
# Intrinsic Theta Frequency: 8.65 Hz

# %% [markdown]
# ## Now calculate theta skipping index and analyse the relationship between skipping index and and the degree of phase precession

# %%
fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)

ax = plot_thetaskipping(ax, autocorrelogram)
plt.tight_layout()

plt.savefig('/home/zilong/Desktop/HDPhasePrecession/figures/thetaskipping.pdf')
# Out:
# Intrinsic Theta Frequency: 8.40 Hz

# %%
base_dir = '/home/zilong/Desktop/HDPhasePrecession/LomiData'
output_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/thetaskipping/all/'
output_skip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/thetaskipping/skip/'
output_nonskip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/thetaskipping/nonskip/'
output_nontheta_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/thetaskipping/nontheta/'

# Configuration
config = {
    'hd_bins': 60,
    'hd_boxcar': 3,
    'speed_threshold': 0.5,
    'duration_threshold': 0.5,
    'speed_smooth_sigma': 40,  #0.8,0.8,40 gives 43% pp cells
    'movingdirection_sigma': 5, #time bin size 20 ms, so 5 is 100 ms
    'interpolation_factor': 1, #1 is 0.02s, and 2 is 0.01s
    'IFR_window':0.2
}

# Create output directories if they don't exist
for dir_path in [output_dir, output_skip_dir, output_nonskip_dir, output_nontheta_dir]:
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)    
    os.makedirs(dir_path)

theta_ppp = []
theta_clr = []
theta_TS = []


total_hd_cells = 0

matnames = {}

# Iterate through each subfolder in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    if os.path.isdir(subdir_path):
        # Iterate through each .mat file in the subfolder
        for file in os.listdir(subdir_path):
            if file.endswith('_sdata.mat'):
                file_path = os.path.join(subdir_path, file)
                print(f"Processing {file_path}")
                ratname = file.split('_')[0]
                data_dict = HD_utils.load_data(ratname, file_path)
                
                if data_dict is not None:
                    ppoh = data_dict['poh']
                    pot = data_dict['pot'].flatten()
                    
                    ppox = data_dict['ppox'].flatten()
                    ppoy = data_dict['ppoy'].flatten()
                    global_freq = data_dict['global_freq'][0][0]
                    
                    #interpolte pot 
                    sampling_interval = np.diff(pot).mean()
                    new_interval = sampling_interval / config['interpolation_factor']
                    pot_interp = np.arange(0, pot[-1], new_interval)
                    
                    for cell_name, cell_data in data_dict['cells_data'].items():
                        psph = cell_data['psph'].flatten()
                        pspt = cell_data['pspt'].flatten()
                        spike_phase = cell_data['spike_phase'].flatten()
                        hd_pval = cell_data['pval'][0][0]
                        hd_mean = cell_data['hd_mean'][0][0]
                        hd_std = cell_data['hd_std'][0][0]
                        tune_width = cell_data['tune_width'][0][0]
                        autocorrelogram = cell_data['autocorrelogram']
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        hd_rayleigh = cell_data['hd_rayleigh'][0][0]
                        hd_rayleigh_shuffle_99 = cell_data['hd_rayleigh_shuffle_99'][0][0]
                        peak_fr = cell_data['peak_fr'][0][0]
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        cell_type = cell_data['cell_type']
                        
                        #store matname for each cell
                        matnames[cell_name] = [ratname, file_path]
                        
                        #if hd_pval < 0.05: #select only head direction tuned cells
                        if hd_rayleigh > hd_rayleigh_shuffle_99 and peak_fr > 1: #select only head direction tuned cells with rayleigh vector > 99% shuffle and the peak firing rate in the directional field is greater than 1 Hz
                            try:
                                #get results for phase precession against tuning angle
                                pval, clr = get_phaseprecession(ppoh, pot, pspt, psph, hd_mean, spike_phase, config)
                                
                                fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)
                                ax, TS = plot_thetaskipping(ax, autocorrelogram)
                                
                                output_path = os.path.join(output_dir, f"{cell_name}--{np.round(TS, 2)}Hz.pdf")
                                
                                plt.tight_layout()
                                plt.savefig(output_path)
                            
                                #save fig according to cell type in different folders
                                if 'Strong ThetaxHD' in cell_type: #This is a theta modulated HD cell
                                    theta_ppp.append(pval)
                                    theta_clr.append(clr)
                                    theta_TS.append(TS)
                                    
                                    if 'skip'in cell_type: #this is a theta skipping cell
                                        output_skip_path = os.path.join(output_skip_dir, f"{cell_name}--{np.round(TS, 2)}Hz.pdf")
                                        plt.savefig(output_skip_path)
                                    elif 'Strong ThetaxHD' in cell_type: #this is a theta modulated non-skipping cell
                                        output_nonskip_path = os.path.join(output_nonskip_dir, f"{cell_name}--{np.round(TS, 2)}Hz.pdf")
                                        plt.savefig(output_nonskip_path)
                                elif 'HDC' in cell_type:
                                    output_nontheta_path = os.path.join(output_nontheta_dir, f"{cell_name}--{np.round(TS, 2)}Hz.pdf")
                                    plt.savefig(output_nontheta_path)
                                    
                                plt.close(fig)
                                total_hd_cells += 1
                            except Exception as e:
                                plt.close(fig)
                                print(f"Error processing {cell_name}: {e}")
                        
print(f"Total number of HD cells processed: {total_hd_cells}")
# Out:
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_100919_T1_sdata.mat
# Omega: 14.84 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 16.12 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 13.47 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 16.39 Hz
# Theta Cycle Skipping Index: -0.49
# Omega: 17.25 Hz
# Theta Cycle Skipping Index: -0.15
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_250719_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -1.00
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090819_T1_sdata.mat
# Omega: 16.71 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 17.18 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 12.31 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 11.99 Hz
# Theta Cycle Skipping Index: -0.28
# Omega: 14.34 Hz
# Theta Cycle Skipping Index: -0.19
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_230819_T1_sdata.mat
# Omega: 11.62 Hz
# Theta Cycle Skipping Index: -0.54
# Omega: 17.46 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 16.10 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 16.67 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 17.46 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 17.22 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 12.90 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 17.34 Hz
# Theta Cycle Skipping Index: -0.22
# Omega: 17.07 Hz
# Theta Cycle Skipping Index: -0.16
# Omega: 17.45 Hz
# Theta Cycle Skipping Index: -0.64
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200819_T1_sdata.mat
# Omega: 16.69 Hz
# Theta Cycle Skipping Index: -0.47
# Omega: 17.50 Hz
# Theta Cycle Skipping Index: -0.41
# Omega: 13.61 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 17.39 Hz
# Theta Cycle Skipping Index: -0.31
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_150819_T1_sdata.mat
# Omega: 11.39 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 11.69 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.16
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 15.44 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 14.30 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_290719_T3_sdata.mat
# Omega: 15.33 Hz
# Theta Cycle Skipping Index: -0.40
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050819_T1_sdata.mat
# Omega: 15.38 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.28
# Omega: 14.55 Hz
# Theta Cycle Skipping Index: -0.47
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260819_T1_sdata.mat
# Omega: 16.98 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 16.87 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 12.04 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 17.29 Hz
# Theta Cycle Skipping Index: -0.21
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_020819_T3_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 15.66 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 15.49 Hz
# Theta Cycle Skipping Index: -0.24
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120819_T2_sdata.mat
# Omega: 11.87 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 16.59 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 12.51 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 12.65 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 14.63 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 17.39 Hz
# Theta Cycle Skipping Index: -0.35
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_240719_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.32
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060819_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 15.85 Hz
# Theta Cycle Skipping Index: -0.34
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_310719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090919_T1_sdata.mat
# Omega: 17.03 Hz
# Theta Cycle Skipping Index: -0.37
# Omega: 16.05 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.51
# Omega: 17.18 Hz
# Theta Cycle Skipping Index: -0.28
# Omega: 10.02 Hz
# Theta Cycle Skipping Index: -0.62
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200919_T1_sdata.mat
# Omega: 14.79 Hz
# Theta Cycle Skipping Index: -0.48
# Omega: 11.44 Hz
# Theta Cycle Skipping Index: -0.60
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_130819_T1_sdata.mat
# Omega: 17.36 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.47
# Omega: 11.43 Hz
# Theta Cycle Skipping Index: -0.43
# Omega: 14.39 Hz
# Theta Cycle Skipping Index: -0.48
# Omega: 17.79 Hz
# Theta Cycle Skipping Index: -0.31
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_280819_T1_sdata.mat
# Omega: 12.77 Hz
# Theta Cycle Skipping Index: -0.47
# Omega: 10.01 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 17.11 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 17.40 Hz
# Theta Cycle Skipping Index: -0.22
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050919_T1_sdata.mat
# Omega: 16.94 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 16.87 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 17.01 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 10.37 Hz
# Theta Cycle Skipping Index: -0.45
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120919_T1_sdata.mat
# Omega: 14.85 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 17.24 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 17.24 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 12.42 Hz
# Theta Cycle Skipping Index: -0.49
# Omega: 11.46 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 17.11 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 12.94 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190919_T1_sdata.mat
# Omega: 13.76 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 14.25 Hz
# Theta Cycle Skipping Index: -0.59
# Omega: 17.46 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 11.05 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 16.86 Hz
# Theta Cycle Skipping Index: -0.44
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060919_T1_sdata.mat
# Omega: 17.35 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.13
# Omega: 15.52 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 17.38 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 16.57 Hz
# Theta Cycle Skipping Index: -0.55
# Omega: 14.19 Hz
# Theta Cycle Skipping Index: -0.22
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_210819_T1_sdata.mat
# Omega: 17.25 Hz
# Theta Cycle Skipping Index: -0.17
# Omega: 14.79 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 17.48 Hz
# Theta Cycle Skipping Index: -0.30
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190819_T1_sdata.mat
# Omega: 17.21 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_080819_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 17.16 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 12.72 Hz
# Theta Cycle Skipping Index: -0.47
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160819_T1_sdata.mat
# Omega: 12.19 Hz
# Theta Cycle Skipping Index: -0.51
# Omega: 13.03 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 17.11 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 10.13 Hz
# Theta Cycle Skipping Index: -0.58
# Omega: 17.29 Hz
# Theta Cycle Skipping Index: -0.14
# Omega: 17.35 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 17.42 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.94
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_140819_T1_sdata.mat
# Omega: 15.83 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 12.44 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.65
# Omega: 15.22 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 11.70 Hz
# Theta Cycle Skipping Index: -0.66
# Omega: 14.15 Hz
# Theta Cycle Skipping Index: -0.49
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_220819_T1_sdata.mat
# Omega: 16.76 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 17.42 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 14.22 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 17.26 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 17.10 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 13.56 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 12.43 Hz
# Theta Cycle Skipping Index: -0.60
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180819_T1_sdata.mat
# Omega: 17.65 Hz
# Theta Cycle Skipping Index: -0.41
# Omega: 17.89 Hz
# Theta Cycle Skipping Index: -0.28
# Omega: 14.09 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 14.54 Hz
# Theta Cycle Skipping Index: -0.42
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160919_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 16.36 Hz
# Theta Cycle Skipping Index: -0.20
# Omega: 17.38 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 11.79 Hz
# Theta Cycle Skipping Index: -0.43
# Omega: 17.08 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 11.09 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 17.25 Hz
# Theta Cycle Skipping Index: -0.22
# Omega: 10.10 Hz
# Theta Cycle Skipping Index: -0.48
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180919_T1_sdata.mat
# Omega: 12.02 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 11.20 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 16.61 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_31032020_T2_sdata.mat
# Omega: 17.83 Hz
# Theta Cycle Skipping Index: -0.37
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09032020_T4_sdata.mat
# Omega: 16.44 Hz
# Theta Cycle Skipping Index: -1.00
# Omega: 16.97 Hz
# Theta Cycle Skipping Index: -0.17
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_23032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.98
# Omega: 12.23 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.63
# Omega: 13.73 Hz
# Theta Cycle Skipping Index: -0.27
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10042020_T1_sdata.mat
# Omega: 11.99 Hz
# Theta Cycle Skipping Index: -0.53
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.09
# Error processing rR448_10042020_t4_c1: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_11032020_T1_sdata.mat
# Omega: 13.14 Hz
# Theta Cycle Skipping Index: -0.15
# Omega: 17.66 Hz
# Theta Cycle Skipping Index: -0.50
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_20032020_T3_sdata.mat
# Omega: 17.75 Hz
# Theta Cycle Skipping Index: -0.69
# Omega: 17.21 Hz
# Theta Cycle Skipping Index: -0.99
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.45
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14042020_T2_sdata.mat
# Omega: 16.99 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 15.73 Hz
# Theta Cycle Skipping Index: -0.67
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.64
# Omega: 16.87 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 11.12 Hz
# Theta Cycle Skipping Index: -0.61
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_24032020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 10.05 Hz
# Theta Cycle Skipping Index: -0.46
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16032020_T4_sdata.mat
# Omega: 12.14 Hz
# Theta Cycle Skipping Index: -0.78
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_03042020_T3_sdata.mat
# Omega: 17.42 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 14.13 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 17.30 Hz
# Theta Cycle Skipping Index: -0.14
# Omega: 16.65 Hz
# Theta Cycle Skipping Index: -0.10
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_06042020_T1_sdata.mat
# Omega: 15.61 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 16.49 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 13.00 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 17.66 Hz
# Theta Cycle Skipping Index: -0.20
# Error processing rR448_06042020_t4_c1: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15042020_T1_sdata.mat
# Omega: 17.85 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 10.75 Hz
# Theta Cycle Skipping Index: -0.57
# Omega: 14.30 Hz
# Theta Cycle Skipping Index: -0.51
# Omega: 17.46 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 15.36 Hz
# Theta Cycle Skipping Index: -0.18
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_25032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.13
# Omega: 12.83 Hz
# Theta Cycle Skipping Index: -0.65
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.72
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.48
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_01042020_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 17.97 Hz
# Theta Cycle Skipping Index: -0.28
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 15.88 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 11.12 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.11
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16042020_T1_sdata.mat
# Omega: 16.82 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 16.53 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 13.67 Hz
# Theta Cycle Skipping Index: -0.42
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09042020_T1_sdata.mat
# Omega: 17.15 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 17.09 Hz
# Theta Cycle Skipping Index: -0.13
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_07042020_T1_sdata.mat
# Omega: 13.85 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 14.10 Hz
# Theta Cycle Skipping Index: -0.14
# Omega: 10.77 Hz
# Theta Cycle Skipping Index: -0.57
# Omega: 17.63 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 15.62 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 16.11 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 16.60 Hz
# Theta Cycle Skipping Index: -0.15
# Omega: 17.66 Hz
# Theta Cycle Skipping Index: -0.20
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10032020_T5_sdata.mat
# Omega: 17.93 Hz
# Theta Cycle Skipping Index: -0.73
# Omega: 17.87 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 15.54 Hz
# Theta Cycle Skipping Index: -0.09
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_12032020_T3_sdata.mat
# Omega: 17.54 Hz
# Theta Cycle Skipping Index: -0.65
# Omega: 17.50 Hz
# Theta Cycle Skipping Index: -0.10
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_08042020_T1_sdata.mat
# Omega: 16.35 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 12.26 Hz
# Theta Cycle Skipping Index: -0.20
# Omega: 17.88 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 16.89 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 17.64 Hz
# Theta Cycle Skipping Index: -0.24
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_26032020_T1_sdata.mat
# Omega: 17.47 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.72
# Omega: 16.96 Hz
# Theta Cycle Skipping Index: -0.62
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.46
# Omega: 17.40 Hz
# Theta Cycle Skipping Index: -0.55
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13042020_T1_sdata.mat
# Omega: 17.50 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 14.65 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 14.29 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 16.94 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 16.64 Hz
# Theta Cycle Skipping Index: -0.37
# Omega: 17.67 Hz
# Theta Cycle Skipping Index: -0.52
# Omega: 17.18 Hz
# Theta Cycle Skipping Index: -0.09
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.20
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 17.94 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.69
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.86
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13032020_T8_sdata.mat
# Omega: 17.18 Hz
# Theta Cycle Skipping Index: -0.63
# Omega: 16.38 Hz
# Theta Cycle Skipping Index: -0.13
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_19032020_T1_sdata.mat
# Omega: 17.29 Hz
# Theta Cycle Skipping Index: -0.52
# Omega: 17.00 Hz
# Theta Cycle Skipping Index: -0.13
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_18032020_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 17.89 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 14.01 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.33
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_30032020_T3_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.65
# Omega: 17.92 Hz
# Theta Cycle Skipping Index: -0.40
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_22032020_T2_sdata.mat
# Omega: 11.90 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 17.69 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 11.98 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 12.35 Hz
# Theta Cycle Skipping Index: -0.45
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15032020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.46
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.14
# Omega: 17.89 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.52
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_081019_T1_sdata.mat
# Omega: 17.56 Hz
# Theta Cycle Skipping Index: -0.65
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_310719_T1_sdata.mat
# Omega: 17.44 Hz
# Theta Cycle Skipping Index: -0.44
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_040719_T1_sdata.mat
# Omega: 14.42 Hz
# Theta Cycle Skipping Index: -0.56
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180919_T1_sdata.mat
# Omega: 17.90 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 15.83 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 13.01 Hz
# Theta Cycle Skipping Index: -0.35
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060919_T1_sdata.mat
# Omega: 17.79 Hz
# Theta Cycle Skipping Index: -0.40
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_031019_T1_sdata.mat
# Omega: 17.18 Hz
# Theta Cycle Skipping Index: -0.26
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_280619_T1b_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190819_T1_sdata.mat
# Omega: 17.68 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 17.61 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 16.49 Hz
# Theta Cycle Skipping Index: -0.24
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080719_T1_sdata.mat
# Omega: 17.66 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.18
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190919_T1_sdata.mat
# Omega: 17.63 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 17.34 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 12.97 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060819_T1_sdata.mat
# Omega: 13.52 Hz
# Theta Cycle Skipping Index: -0.20
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.46
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.42
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_071019_T1_sdata.mat
# Omega: 17.17 Hz
# Theta Cycle Skipping Index: -0.29
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_110919_T1_sdata.mat
# Omega: 17.48 Hz
# Theta Cycle Skipping Index: -0.83
# Omega: 17.71 Hz
# Theta Cycle Skipping Index: -0.33
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050919_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.22
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130919_T1_sdata.mat
# Omega: 17.13 Hz
# Theta Cycle Skipping Index: -0.87
# Omega: 17.12 Hz
# Theta Cycle Skipping Index: -0.29
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_091019_T1_sdata.mat
# Omega: 17.55 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.61
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_120919_T1_sdata.mat
# Omega: 17.22 Hz
# Theta Cycle Skipping Index: -0.90
# Omega: 17.52 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 17.57 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 17.64 Hz
# Theta Cycle Skipping Index: -0.18
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090819_T1_sdata.mat
# Omega: 17.97 Hz
# Theta Cycle Skipping Index: -0.17
# Omega: 17.88 Hz
# Theta Cycle Skipping Index: -0.52
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260719_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_170919_T1_sdata.mat
# Omega: 17.30 Hz
# Theta Cycle Skipping Index: -0.81
# Omega: 17.77 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 13.10 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 17.17 Hz
# Theta Cycle Skipping Index: -0.83
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260819_T1_sdata.mat
# Omega: 12.09 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 12.86 Hz
# Theta Cycle Skipping Index: -0.35
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_030919_T1_sdata.mat
# Omega: 15.37 Hz
# Theta Cycle Skipping Index: -0.08
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_101019_T2_sdata.mat
# Omega: 13.16 Hz
# Theta Cycle Skipping Index: -0.10
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_010719_T7_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.96
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090919_T1_sdata.mat
# Omega: 17.80 Hz
# Theta Cycle Skipping Index: -0.66
# Omega: 17.63 Hz
# Theta Cycle Skipping Index: -0.15
# Omega: 17.25 Hz
# Theta Cycle Skipping Index: -0.15
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260619_T1_sdata.mat
# Omega: 17.90 Hz
# Theta Cycle Skipping Index: -0.83
# Omega: 17.86 Hz
# Theta Cycle Skipping Index: -0.46
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_041019_T2_sdata.mat
# Omega: 17.25 Hz
# Theta Cycle Skipping Index: -0.98
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.97
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080819_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.69
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_110119_T4_sdata.mat
# Omega: 17.53 Hz
# Theta Cycle Skipping Index: -0.34
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030119_T4_sdata.mat
# Omega: 16.46 Hz
# Theta Cycle Skipping Index: -0.84
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_050119_T2_sdata.mat
# Omega: 12.34 Hz
# Theta Cycle Skipping Index: -0.74
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_280219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160119_T4_sdata.mat
# Omega: 16.88 Hz
# Theta Cycle Skipping Index: -0.69
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_130119_T2_sdata.mat
# Omega: 17.51 Hz
# Theta Cycle Skipping Index: -0.35
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190219_T2_sdata.mat
# Omega: 17.62 Hz
# Theta Cycle Skipping Index: -0.20
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120119_T6_sdata.mat
# Omega: 17.48 Hz
# Theta Cycle Skipping Index: -0.41
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220219_T2_sdata.mat
# Omega: 16.60 Hz
# Theta Cycle Skipping Index: -0.41
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_310119_T4_sdata.mat
# Omega: 16.56 Hz
# Theta Cycle Skipping Index: -0.81
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_010219_T2_sdata.mat
# Omega: 16.57 Hz
# Theta Cycle Skipping Index: -0.70
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070119_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190119_T1_sdata.mat
# Omega: 15.85 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 16.80 Hz
# Theta Cycle Skipping Index: -0.87
# Omega: 14.95 Hz
# Theta Cycle Skipping Index: -0.66
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T2_sdata.mat
# Omega: 17.05 Hz
# Theta Cycle Skipping Index: -0.31
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_090219_T1_sdata.mat
# Omega: 12.41 Hz
# Theta Cycle Skipping Index: -0.32
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_290119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_170119_T8_sdata.mat
# Omega: 10.28 Hz
# Theta Cycle Skipping Index: -0.26
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_150219_T1_sdata.mat
# Omega: 10.17 Hz
# Theta Cycle Skipping Index: -0.14
# Omega: 16.82 Hz
# Theta Cycle Skipping Index: -0.49
# Omega: 14.09 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 16.35 Hz
# Theta Cycle Skipping Index: -0.61
# Omega: 16.36 Hz
# Theta Cycle Skipping Index: -0.24
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_140219_T4_sdata.mat
# Omega: 16.09 Hz
# Theta Cycle Skipping Index: -0.41
# Omega: 16.36 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 17.79 Hz
# Theta Cycle Skipping Index: -0.30
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_270119_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120219_T1_sdata.mat
# Omega: 17.23 Hz
# Theta Cycle Skipping Index: -0.35
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T5_sdata.mat
# Omega: 17.78 Hz
# Theta Cycle Skipping Index: -0.44
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070219_T5_sdata.mat
# Omega: 16.82 Hz
# Theta Cycle Skipping Index: -0.45
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_080119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_27032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.89
# Omega: 17.36 Hz
# Theta Cycle Skipping Index: -0.61
# Omega: 17.56 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 17.62 Hz
# Theta Cycle Skipping Index: -0.50
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.41
# Omega: 17.48 Hz
# Theta Cycle Skipping Index: -0.48
# Omega: 12.74 Hz
# Theta Cycle Skipping Index: -0.10
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_26032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.95
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.29
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.57
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 17.92 Hz
# Theta Cycle Skipping Index: -0.37
# Omega: 17.99 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 14.15 Hz
# Theta Cycle Skipping Index: -0.16
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.46
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.50
# Omega: 17.89 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 17.03 Hz
# Theta Cycle Skipping Index: -0.20
# Omega: 17.35 Hz
# Theta Cycle Skipping Index: -0.39
# Omega: 16.82 Hz
# Theta Cycle Skipping Index: -0.86
# Omega: 16.11 Hz
# Theta Cycle Skipping Index: -0.55
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_30032020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.85
# Omega: 17.57 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 17.14 Hz
# Theta Cycle Skipping Index: -0.45
# Omega: 14.44 Hz
# Theta Cycle Skipping Index: -0.33
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15032020_T1_sdata.mat
# Omega: 17.88 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.59
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_07042020_T1_sdata.mat
# Omega: 13.87 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 17.36 Hz
# Theta Cycle Skipping Index: -0.52
# Omega: 17.82 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.30
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.56
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 17.65 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 11.61 Hz
# Theta Cycle Skipping Index: -0.29
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_17032020_T1_sdata.mat
# Omega: 17.19 Hz
# Theta Cycle Skipping Index: -0.46
# Omega: 17.72 Hz
# Theta Cycle Skipping Index: -0.25
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10042020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.34
# Omega: 17.69 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 17.62 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 17.28 Hz
# Theta Cycle Skipping Index: -0.16
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_16032020_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 15.60 Hz
# Theta Cycle Skipping Index: -0.37
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_31032020_T1_sdata.mat
# Omega: 17.40 Hz
# Theta Cycle Skipping Index: -0.49
# Omega: 17.80 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 12.37 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 12.17 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 17.90 Hz
# Theta Cycle Skipping Index: -0.61
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.28
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_11032020_T2_sdata.mat
# Omega: 17.78 Hz
# Theta Cycle Skipping Index: -0.39
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_20032020_T1_sdata.mat
# Omega: 17.61 Hz
# Theta Cycle Skipping Index: -0.78
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.38
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.37
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_24032020_T1_sdata.mat
# Omega: 17.13 Hz
# Theta Cycle Skipping Index: -0.57
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 17.71 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 17.94 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.35
# Omega: 17.88 Hz
# Theta Cycle Skipping Index: -0.42
# Omega: 17.49 Hz
# Theta Cycle Skipping Index: -0.15
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_02042020_T1_sdata.mat
# Omega: 17.00 Hz
# Theta Cycle Skipping Index: -0.33
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.60
# Omega: 17.75 Hz
# Theta Cycle Skipping Index: -0.73
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.13
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.19
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_09042020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 12.47 Hz
# Theta Cycle Skipping Index: -0.70
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.12
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.18
# Omega: 13.45 Hz
# Theta Cycle Skipping Index: -0.56
# Omega: 17.37 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 17.37 Hz
# Theta Cycle Skipping Index: -0.31
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_18032020_T1_sdata.mat
# Omega: 16.59 Hz
# Theta Cycle Skipping Index: -0.21
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.26
# Omega: 17.60 Hz
# Theta Cycle Skipping Index: -0.48
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13042020_T1_sdata.mat
# Omega: 12.94 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 15.51 Hz
# Theta Cycle Skipping Index: -0.36
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.25
# Omega: 17.90 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 17.90 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.58
# Omega: 13.64 Hz
# Theta Cycle Skipping Index: -0.55
# Omega: 17.09 Hz
# Theta Cycle Skipping Index: -0.98
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_01042020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.91
# Omega: 17.28 Hz
# Theta Cycle Skipping Index: -0.48
# Omega: 17.93 Hz
# Theta Cycle Skipping Index: -0.24
# Omega: 17.44 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 17.45 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.55
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_25032020_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.56
# Omega: 17.95 Hz
# Theta Cycle Skipping Index: -0.15
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_19032020_T2_sdata.mat
# Omega: 17.75 Hz
# Theta Cycle Skipping Index: -0.52
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_22032020_T3_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.60
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.80
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.92
# Omega: 17.38 Hz
# Theta Cycle Skipping Index: -0.31
# Omega: 17.22 Hz
# Theta Cycle Skipping Index: -0.43
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14042020_T1_sdata.mat
# Omega: 17.94 Hz
# Theta Cycle Skipping Index: -0.37
# Omega: 17.99 Hz
# Theta Cycle Skipping Index: -0.23
# Omega: 16.38 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.49
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14032020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.40
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.49
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_03042020_T1_sdata.mat
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.85
# Omega: 17.50 Hz
# Theta Cycle Skipping Index: -0.27
# Omega: 17.81 Hz
# Theta Cycle Skipping Index: -0.17
# Omega: 17.72 Hz
# Theta Cycle Skipping Index: -0.19
# Omega: 16.40 Hz
# Theta Cycle Skipping Index: -0.22
# Error processing rR449_03042020_t2_c2: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Omega: 10.87 Hz
# Theta Cycle Skipping Index: -0.13
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13032020_T1_sdata.mat
# Omega: 16.72 Hz
# Theta Cycle Skipping Index: -0.16
# Omega: 17.91 Hz
# Theta Cycle Skipping Index: -0.75
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_08042020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.22
# Omega: 11.68 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 17.48 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.10
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.13
# Omega: 11.11 Hz
# Theta Cycle Skipping Index: -0.11
# Omega: 10.00 Hz
# Theta Cycle Skipping Index: -0.17
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_23032020_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.44
# Omega: 17.85 Hz
# Theta Cycle Skipping Index: -0.64
# Omega: 10.13 Hz
# Theta Cycle Skipping Index: -0.99
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.37
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_120319_T3_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.85
# Omega: 17.56 Hz
# Theta Cycle Skipping Index: -0.28
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_060319_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.32
# Omega: 17.16 Hz
# Theta Cycle Skipping Index: -0.44
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_280319_T5_sdata.mat
# Omega: 15.41 Hz
# Theta Cycle Skipping Index: -0.33
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_130319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_220319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_150319_T2_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.56
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_180319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_050319_T1_sdata.mat
# Omega: 17.38 Hz
# Theta Cycle Skipping Index: -0.53
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_170319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_140319_T1_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.45
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_260319_T3_sdata.mat
# Omega: 18.00 Hz
# Theta Cycle Skipping Index: -0.41
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_080319_T2_sdata.mat
# Total number of HD cells processed: 458

# %%
#plot theta_clr against theta_TS for theta_ppp<0.05
fig, ax = plt.subplots(1, 1, figsize=(2.8, 2.4), dpi=300)

indx = np.where(np.array(theta_ppp) < 0.05)[0]
ax.scatter(np.array(theta_TS)[indx], np.array(theta_clr)[indx], color='red', label='Theta', s=1)

ax.set_xlabel('Theta skipping index', fontsize=labelsize)
ax.set_ylabel('C-L corr. coef.', fontsize=labelsize)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
theta_TS
# Out:
# [8.644746889535824,
#  8.738361366093905,
#  8.73125893958663,
#  8.619244360220627,
#  8.646514202072696,
#  8.66891234123447,
#  8.754599633487171,
#  8.665745284595829,
#  8.771791389432437,
#  8.70924454116322,
#  9.118414321565247,
#  8.93600885087699,
#  8.48176317440718,
#  8.648995628628132,
#  8.636568015398657,
#  9.177301636094281,
#  9.131294152761798,
#  8.668019363233531,
#  8.607098245260332,
#  8.6841955990835,
#  8.895550850792977,
#  8.554969780662724,
#  8.71890174654153,
#  9.192171832954632,
#  8.618798148202652,
#  8.788526785399426,
#  8.553187623098967,
#  8.733878097022348,
#  8.74378103649259,
#  8.679475174589951,
#  8.531370759826036,
#  8.93095351505526,
#  8.62987351263414,
#  9.419377088409242,
#  8.740310687948513,
#  8.62524833894198,
#  8.554256588228554,
#  8.401335332400366,
#  8.579593657188461,
#  8.68324819498222,
#  8.748983911031184,
#  9.362204611253828,
#  8.713779668075036,
#  8.635415293327044,
#  8.554924979728533,
#  8.112890767563027,
#  8.8365934378626,
#  8.955112873048217,
#  8.160344345904907,
#  9.798791158983045,
#  8.36060005120292,
#  8.707109794588174,
#  8.67080425580002,
#  8.624013344905137,
#  9.53069714450738,
#  8.915580926265301,
#  8.566078725437745,
#  8.483141441927295,
#  9.137164248041417,
#  9.376056002846607,
#  8.123667210521454,
#  9.213672545366316,
#  8.867006341822142,
#  8.866391912516223,
#  8.876631025350866,
#  8.825395982842652,
#  9.642858765060984,
#  8.954494082778606,
#  8.305017896497715,
#  8.770818653730226,
#  9.23990723392061,
#  8.64995852368909,
#  8.835186254761137,
#  9.665874162613575,
#  9.099348674496312,
#  9.098491422715014,
#  9.157080746892843,
#  9.144594661490228,
#  9.03805789327522,
#  9.050282868204174,
#  9.0617343819784,
#  8.959715451192125,
#  9.109128752282297,
#  8.183219720241286,
#  9.14242086453398,
#  8.839219010400955,
#  8.836457192106257,
#  8.964687462486543,
#  8.91499023354779,
#  8.773737290360415,
#  8.941592519144296,
#  8.837310895641105,
#  8.838885528594208,
#  8.74077998749392,
#  9.112191893893108,
#  9.072713620176746,
#  8.724039544660322,
#  8.933300718295484,
#  8.596125657452914,
#  9.301643730222587,
#  9.42282922267921,
#  9.036676377350796,
#  9.571106142128588,
#  9.497489233980735,
#  8.70382286062068,
#  8.094868988542071,
#  8.680636563707965,
#  9.329008344426109,
#  8.920193475223174,
#  8.73974147583092,
#  9.344875612567922,
#  8.762312286914968,
#  8.953334420321363,
#  8.946525690806723,
#  9.225166135971598,
#  8.766367291875712,
#  8.8171107323166,
#  9.061592687317335,
#  8.949755626469054,
#  8.672457865229783,
#  8.911688923654616,
#  8.85612836459192,
#  9.076990336632115,
#  8.839752684496087,
#  8.801503398994036,
#  9.071930955873869,
#  9.146757499532582,
#  8.927328631971177,
#  8.928106473028997,
#  9.068054317424194,
#  8.705555219707124,
#  8.554927034181645,
#  8.865647951807036,
#  8.759857766455601,
#  8.791267944533034,
#  8.82122442516339,
#  8.99838869001804,
#  8.932712914303641,
#  8.71941051956403,
#  8.794671443566342,
#  8.653452152823977,
#  8.866094751549852,
#  8.838914900009039,
#  7.0469744633308204,
#  8.82284696389279,
#  8.619290367389949,
#  9.01782595738522,
#  8.919775277804293,
#  9.32965540214863,
#  8.76671531226076,
#  8.279902739782209,
#  8.299738773353669,
#  8.323381801918893,
#  8.47160850647073,
#  8.406311659990658,
#  7.501404286416998,
#  8.505454526064552,
#  8.41246198045113,
#  8.192174453337792,
#  8.028350865906459,
#  8.616153302698454,
#  8.401339963114562,
#  8.92032920613281,
#  8.77979728008269,
#  8.77225442621453,
#  9.139592632518216,
#  9.206059650931767,
#  8.958891636666579,
#  8.996774129521905,
#  9.53385103311165,
#  9.02322070656331,
#  9.169416158812771,
#  8.765812916022915,
#  8.571129196757022,
#  8.95108099503914,
#  8.687447451976508,
#  8.907626059778513,
#  9.200435956438296,
#  9.022503301739036,
#  8.577928315856372,
#  8.957193972402518,
#  9.434972240322915,
#  8.818088992868383,
#  9.391459564930157,
#  9.025595876117821,
#  9.270470247392204,
#  8.902844194726116,
#  8.882216771512837,
#  9.228124114405947,
#  9.006578877068087,
#  8.884954805041646,
#  9.117332288704267,
#  9.49394904164907,
#  9.392517844354652,
#  8.58688403347174,
#  9.266085458172046,
#  9.053829766982814,
#  8.74994831210458,
#  8.534866882799781,
#  8.884419435498287,
#  9.130938108961379,
#  8.997144527911527,
#  9.201232844827917,
#  9.39979228209382,
#  8.688761558021591,
#  8.840650504606304,
#  8.960800373456726,
#  9.27852397404707,
#  9.012348332206349,
#  9.225901570415887,
#  9.18203573163358,
#  9.004458531399376,
#  8.732227906592147,
#  9.19650703642014,
#  9.366356158093101,
#  8.967560503832186,
#  8.31412192460619,
#  9.057784376824314,
#  9.3619329077331,
#  9.135711844590311,
#  8.747739701456258,
#  8.809355944247425,
#  8.922095009051473,
#  9.58613067969517,
#  9.108616169632466,
#  9.098561174276888,
#  8.758807270663942,
#  9.075538380610872,
#  9.223770374149057,
#  8.800771355987852,
#  9.180591234495683,
#  8.971087505549555,
#  8.528760333280717,
#  9.332696694914036,
#  8.751541460820873,
#  9.642814275867563,
#  8.93585468992336,
#  9.770161847850126,
#  8.69008547911523]
