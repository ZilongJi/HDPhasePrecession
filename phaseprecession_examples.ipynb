# %% [markdown]
# # This code is to get examples of phase precession of turning angles in HD cells

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve1d
from numpy import deg2rad
import sys
sys.path.append('/home/zilong/Desktop/HDPhasePrecession/CircularLinearReg')
from core import cl_corr
import HD_utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot_head_direction_tuning(ax, ppoh, psph, config, pos_tb=0.02):
    """
    Plot the head direction tuning map in a polar plot.

    Parameters:
    ax : matplotlib.axes._subplots.PolarAxesSubplot
        The polar axes to plot on.
    ppoh : np.array
        Array of session head direction angles in degrees.
    psph : np.array
        Array of cell head direction angles in degrees.
    pos_tb : float
        Time base for converting session HD to time.
    cell_name : str
        Name of the cell for which the tuning map is plotted.
    config : dict
        Configuration dictionary containing 'hd_bins' and 'hd_boxcar' parameters.
    """

    # Convert angles to radians
    ppoh_rad = deg2rad(ppoh)
    psph_rad = deg2rad(psph)

    # Calculate histograms for session and cell head directions
    hd1, _ = np.histogram(ppoh_rad, bins=config['hd_bins'], range=(0, 2 * np.pi))
    hd2, _ = np.histogram(psph_rad, bins=config['hd_bins'], range=(0, 2 * np.pi))

    # Boxcar filter
    boxcar_size = config['hd_boxcar']
    boxcar_filter = np.ones(boxcar_size) / boxcar_size

    # Apply boxcar filter
    hd1_filtered = convolve1d(hd1, boxcar_filter, mode='wrap')
    hd2_filtered = convolve1d(hd2, boxcar_filter, mode='wrap')

    # Convert session HD to time (i.e., dwelling time in each HD bin)
    hd1_time = hd1_filtered * pos_tb

    # Calculate HD firing rate
    hd3 = hd2_filtered / hd1_time

    # Normalize session HD
    hd1_normalized = hd1_time / np.max(hd1_time)

    # Normalize cell HD firing rate
    hd3_normalized = hd3 / np.max(hd3)
    hd3_normalized = hd3_normalized.flatten()

    # Close the loop by appending the first element to the end
    theta = np.linspace(0, 2 * np.pi, config['hd_bins'], endpoint=False)
    theta = np.append(theta, theta[0])
    hd1_normalized = np.append(hd1_normalized, hd1_normalized[0])
    hd3_normalized = np.append(hd3_normalized, hd3_normalized[0])

    # Plot the session head direction with shading
    ax.plot(theta, hd1_normalized, label='Session Head Direction', color='gray')
    ax.fill_between(theta, 0, hd1_normalized, facecolor='gray', alpha=0.2)

    # Plot the cell head direction firing rate
    ax.plot(theta, hd3_normalized, label='Cell Head Direction Firing Rate', color='#38c7ff')
    ax.fill_between(theta, 0, hd3_normalized, facecolor='#38c7ff', alpha=0.5)

    #keep 0 90 180 270 as the xticks
    ax.set_xticks([0, np.pi / 2, np.pi, 3 * np.pi / 2])
    ax.set_xticklabels(['0°', '90°', '180°', '270°'])
    
    #remove yticks
    ax.set_yticks([])
    
    #ax.set_title(cell_name + '\n'+str(np.round(hd_mean,1))+'('+str(np.round(hd_std,1))+')' +'\nRayleigh_p=' + str(np.round(pval, 4)), fontsize=10)
    
    #ax.set_title(f"{cell_name}\nAngle:{hd_mean:.0f} ({hd_std:.0f})\nTuning width:{tune_width:.0f}\nRayleigh_p={pval:.4f}", fontsize=10)
    # ax.legend()
    #set x and y tick as 8 pt
    ax.tick_params(axis='x', labelsize=8)
    ax.tick_params(axis='y', labelsize=8)

    return ax


def plot_phaseprecession(ax, ppoh, pot, pspt, psph, hd_mean, spike_phase, config, addfitline=True):
    
    spike_phase = spike_phase + np.pi #[-pi, pi] -> [0, 2pi]
    
    alpha = 0.4
    speed_threshold = config['speed_threshold']
    duration_threshold = config['duration_threshold']
    speed_smooth_sigma = config['speed_smooth_sigma']
    
    #calculate angular speed
    angular_speed = HD_utils.calculate_angular_speed(ppoh, pot, sigma=speed_smooth_sigma)
    
    #convert psph to radian
    psph = deg2rad(psph)
    hd_mean = deg2rad(hd_mean)
    
    psph_centered = np.mod(psph - hd_mean + np.pi, 2 * np.pi)
    
    #CCW plot in ax1
    continuous_periods_CCW = HD_utils.find_continuous_periods(angular_speed, pot, speed_threshold=-speed_threshold, duration_threshold=duration_threshold)
    indx = []
    for i in range(len(continuous_periods_CCW)):
        indx.extend(np.where((pspt > continuous_periods_CCW[i][0]) & (pspt < continuous_periods_CCW[i][1]))[0])
        
    psph_CCW = psph_centered[indx]
    spike_phase_CCW = spike_phase[indx]
    
    
    #CW plot in ax2
    continuous_periods_CW = HD_utils.find_continuous_periods(angular_speed, pot, speed_threshold=speed_threshold, duration_threshold=duration_threshold)
    #keep the index when pspt is within continuous_periods
    indx = [] 
    for i in range(len(continuous_periods_CW)):
        indx.extend(np.where((pspt > continuous_periods_CW[i][0]) & (pspt < continuous_periods_CW[i][1]))[0])
    
    psph_CW = psph_centered[indx]
    spike_phase_CW = spike_phase[indx]
    
    
    #ax3 plot
    #flip   psph_CCW by 2pi - psph_CCW
    psph_CCW = 2 * np.pi - psph_CCW
    #combine CCW and CW togther and plot
    psph_combined = np.concatenate((psph_CCW, psph_CW))
    spike_phase_combined = np.concatenate((spike_phase_CCW, spike_phase_CW))
    
    circ_lin_corr, pval, slope, phi0, RR = cl_corr(psph_combined, spike_phase_combined, min_slope=-1/2/np.pi, max_slope=0, bootstrap_iter=3000, return_pval=True)

    #if len(psph_combined)>200 then random sample 200 points from it, otherwise plot all points
    if len(psph_combined) > np.inf:
        idx = np.random.choice(len(psph_combined), 200, replace=False)
        psph_combined = psph_combined[idx]
        spike_phase_combined = spike_phase_combined[idx]
         
        ax.scatter(psph_combined, spike_phase_combined, s=0.2, color='black', alpha=alpha)
        ax.scatter(psph_combined, [spike_phase_combined[i] + 2 * np.pi for i in range(len(spike_phase_combined))], s=0.2, color='black', alpha=alpha)
    else:
        ax.scatter(psph_combined, spike_phase_combined, s=0.2, color='black', alpha=alpha)
        ax.scatter(psph_combined, [spike_phase_combined[i] + 2 * np.pi for i in range(len(spike_phase_combined))], s=0.2, color='black', alpha=alpha)
        

    if addfitline:
        # Plot the circular-linear regression
        x = np.linspace(0, 2 * np.pi, 100)
        y = 2 * np.pi * slope * x + phi0
        ax.plot(x, y, color='red', linewidth=1)
        #add intercepr of 2*pi, and plot the line again
        y = 2 * np.pi * slope * x + phi0 + 2 * np.pi
        ax.plot(x, y, color='red', linewidth=1)
        #add intercepr of 4*pi, and plot the line again
        y = 2 * np.pi * slope * x + phi0 + 4 * np.pi
        ax.plot(x, y, color='red', linewidth=1)
        #substrac intercepr of 2*pi, and plot the line again
        y = 2 * np.pi * slope * x + phi0 - 2 * np.pi
        ax.plot(x, y, color='red', linewidth=1)    
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.set_xlim(0, 2*np.pi)
    ax.set_xticks([0, np.pi, 2*np.pi])
    ax.set_xticklabels(["$-\pi$", "$0$", "$\pi$"])
    
    ax.set_ylim(0, 4*np.pi)
    ax.set_yticks([0,  2*np.pi,  4*np.pi])
    ax.set_yticklabels(["$0$", "$2\pi$", "$4\pi$"])
    
    #set tick size as 8 using one line
    ax.tick_params(axis='both', labelsize=8)
    

    return ax, pval, circ_lin_corr

# %%
base_dir = '/home/zilong/Desktop/HDPhasePrecession/LomiData'
output_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/pp_examples/all/'
output_skip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/pp_examples/skip/'
output_nonskip_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/pp_examples/nonskip/'
output_nontheta_dir = '/home/zilong/Desktop/HDPhasePrecession/figures/pp_examples/nontheta/'

# Configuration
config = {
    'hd_bins': 60,
    'hd_boxcar': 3,
    'speed_threshold': 0.8,
    'duration_threshold': 0.8,
    'speed_smooth_sigma': 20,  #0.8,0.8,40 gives 43% pp cells
    'movingdirection_sigma': 5, #time bin size 20 ms, so 5 is 100 ms
    'interpolation_factor': 1, #1 is 0.02s, and 2 is 0.01s
}

# Create output directories if they don't exist
for dir_path in [output_dir, output_skip_dir, output_nonskip_dir, output_nontheta_dir]:
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)    
    os.makedirs(dir_path)

total_hd_cells = 0

all_tw = []
nontheta_tw = []
theta_tw = []
theta_nonskip_tw = []
theta_skip_tw = []

all_ppp = []
nontheta_ppp = []
theta_ppp = []
theta_nonskip_ppp = []
theta_skip_ppp = []

all_ppp_time = []
nontheta_ppp_time = []
theta_ppp_time = []
theta_nonskip_ppp_time = []
theta_skip_ppp_time = []

all_ppp_IFR = []
nontheta_ppp_IFR = []
theta_ppp_IFR = []
theta_nonskip_ppp_IFR = []
theta_skip_ppp_IFR = []

all_clr = []
nontheta_clr = []
theta_clr = []
theta_nonskip_clr = []
theta_skip_clr = []


matnames = {}

# Iterate through each subfolder in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    if os.path.isdir(subdir_path):
        # Iterate through each .mat file in the subfolder
        for file in os.listdir(subdir_path):
            if file.endswith('_sdata.mat'):
                file_path = os.path.join(subdir_path, file)
                print(f"Processing {file_path}")
                ratname = file.split('_')[0]
                data_dict = HD_utils.load_data(ratname, file_path)
                
                if data_dict is not None:
                    ppoh = data_dict['poh']
                    pot = data_dict['pot'].flatten()
                    
                    ppox = data_dict['ppox'].flatten()
                    ppoy = data_dict['ppoy'].flatten()
                    
                    #interpolte pot 
                    sampling_interval = np.diff(pot).mean()
                    new_interval = sampling_interval / config['interpolation_factor']
                    pot_interp = np.arange(0, pot[-1], new_interval)
                    
                    for cell_name, cell_data in data_dict['cells_data'].items():
                        psph = cell_data['psph'].flatten()
                        pspt = cell_data['pspt'].flatten()
                        spike_phase = cell_data['spike_phase'].flatten()
                        hd_pval = cell_data['pval'][0][0]
                        hd_mean = cell_data['hd_mean'][0][0]
                        hd_std = cell_data['hd_std'][0][0]
                        tune_width = cell_data['tune_width'][0][0]
                        autocorrelogram = cell_data['autocorrelogram']
                        intrinsic_freq = cell_data['intrinsic_freq'][0][0]
                        hd_rayleigh = cell_data['hd_rayleigh'][0][0]
                        hd_rayleigh_shuffle_99 = cell_data['hd_rayleigh_shuffle_99'][0][0]
                        peak_fr = cell_data['peak_fr'][0][0]                        
                        cell_type = cell_data['cell_type']
                        
                        
                        #store matname for each cell
                        matnames[cell_name] = [ratname, file_path]
                        
                        # if hd_pval < 0.05: #select only head direction tuned cells
                        if hd_rayleigh > hd_rayleigh_shuffle_99 and peak_fr > 1: #select only head direction tuned cells with rayleigh vector > 99% shuffle and the peak firing rate in the directional field is greater than 1 Hz
                            try:
                                #plot
                                fig = plt.figure(figsize=(3,1.8), dpi=300)
                                gs=fig.add_gridspec(1, 2, width_ratios=[1, 1])
                                
                                #plot head direction tuning map
                                ax0 = fig.add_subplot(gs[0, 0], projection='polar')
                                ax0 = plot_head_direction_tuning(ax0, ppoh, psph, config)
                                
                                #plot phase precession against tuning angle
                                ax1 = fig.add_subplot(gs[0, 1])
                                ax1, pval, clr = plot_phaseprecession(ax1, ppoh, pot, pspt, psph, hd_mean, spike_phase, config)
                                
                                #add a super title
                                ratname = matnames[cell_name][0]
                                tetrode_cell_name = cell_name.split('_')[-2] + ' ' + cell_name.split('_')[-1]
                                if pval<0.001:
                                    fig.suptitle(f"{ratname} {tetrode_cell_name} p<0.001", fontsize=10, y=0.95)
                                else:
                                    fig.suptitle(f"{ratname} {tetrode_cell_name} p={pval:.3f}", fontsize=10, y=0.95)
                                #fig.suptitle(f"{cell_name}\nAngle:{hd_mean:.0f} ({hd_std:.0f})\nTuning width:{tune_width:.0f}\nRayleigh_p={pval:.4f}", fontsize=10)
                                
                                if pval > 0.05:
                                    plt.close(fig)
                                    continue
                                
                                output_path = os.path.join(output_dir, f"{cell_name}.pdf")
                                plt.tight_layout()
                                plt.savefig(output_path)
                                
                                #save tuning width
                                all_tw.append(tune_width)
                                #save ppp 
                                all_ppp.append(pval)
                                #save circ-linear correlation
                                all_clr.append(clr)
                            
                                #save fig according to cell type in different folders
                                if 'Strong ThetaxHD' in cell_type:
                                    
                                    #save tuning width
                                    theta_tw.append(tune_width)
                                    #save ppp
                                    theta_ppp.append(pval)
                                    #save circ-linear correlation
                                    theta_clr.append(clr)
                                                                        
                                    if 'skip'in cell_type:
                                        #save tuning width
                                        theta_skip_tw.append(tune_width)
                                        #save ppp
                                        theta_skip_ppp.append(pval)
                                        #save circ-linear correlation
                                        theta_skip_clr.append(clr)
                                        output_skip_path = os.path.join(output_skip_dir, f"{cell_name}.png")
                                        plt.savefig(output_skip_path)
                                    elif 'Strong ThetaxHD' in cell_type:
                                        #save tuning width
                                        theta_nonskip_tw.append(tune_width)
                                        #save ppp
                                        theta_nonskip_ppp.append(pval)
                                        #save circ-linear correlation
                                        theta_nonskip_clr.append(clr)
                                        output_nonskip_path = os.path.join(output_nonskip_dir, f"{cell_name}.png")
                                        plt.savefig(output_nonskip_path)
                                elif 'HDC' in cell_type:
                                    nontheta_tw.append(tune_width)
                                    nontheta_ppp.append(pval)
                                    
                                    nontheta_clr.append(clr)
                                    output_nontheta_path = os.path.join(output_nontheta_dir, f"{cell_name}.png")
                                    plt.savefig(output_nontheta_path)
                                    
                                plt.close(fig)
                                
                                total_hd_cells += 1
                            except Exception as e:
                                print(f"Error processing {cell_name}: {e}")
                        
print(f"Total number of HD cells processed: {total_hd_cells}")
# Out:
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_100919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_040919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_250719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_020819_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_240719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_260719_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_310719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_280819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_210819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_140819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_270819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_190719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_220819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_160919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r652/R652_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_31032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09032020_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_11032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_20032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14042020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16032020_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_03042020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_25032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_01042020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_16042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_10032020_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_12032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_13032020_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_19032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_18032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_30032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_22032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r448/R448_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_200919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_081019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_310719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_040719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_150819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_031019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_280619_T1b_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_180819_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_220619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_190919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_060819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_071019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_110919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_300919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_130919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_091019_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_120919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260719_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_210619_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050719_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_170919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_030919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_101019_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_230819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_010719_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_050819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_090919_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_260619_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_290719_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_041019_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r651/R651_080819_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_110119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_050119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_030219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_280219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_130119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120119_T6_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_040119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_310119_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_010219_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070119_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_190119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_090219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_060219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_290119_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_170119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_150219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_140219_T4_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_270119_T7_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_220119_T8_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_120219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_200119_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_070219_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_160219_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r762/R762_080119_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_27032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_26032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_30032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_07042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_17032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_16032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_06042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_31032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_11032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_15042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_20032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_24032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_02042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_10032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_09042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_18032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_01042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_25032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_19032020_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_22032020_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_14032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_03042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_13032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_08042020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r449/R449_23032020_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_120319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_060319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_280319_T5_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_130319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_220319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_150319_T2_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_180319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_050319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_170319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_110319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_140319_T1_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_260319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# 'light1' not found in /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_070319_T3_sdata.mat
# Processing /home/zilong/Desktop/HDPhasePrecession/LomiData/DATA r222/R222_080319_T2_sdata.mat
# Total number of HD cells processed: 60
